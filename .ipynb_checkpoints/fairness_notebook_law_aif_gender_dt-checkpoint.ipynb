# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

# %%
from aif360.datasets import AdultDataset, GermanDataset, CompasDataset, BankDataset

# %%
from aif360.datasets import StandardDataset
StandardDataset??

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
import pandas as pd
import statistics
from data_utils import DatasetBuilder
from metrics_utils import compute_metrics, describe_metrics, get_test_metrics, test
from plot_utils import plot
from mitigators import NullMitigator, SyntheticMitigator, DIRMitigator, ReweighMitigator, EGRMitigator, PRMitigator, CPPMitigator, ROMitigator 
from test_algorithms import TestAlgorithms
from plot_utils import plot_algo_lr, plot_algo

# Metrics
from aif360.metrics import BinaryLabelDatasetMetric

# Bias insertion
from oversample import label_bias, selection_bias 
from metrics_utils import get_orig_model_metrics

# %% [markdown]
# ## Arguments & Initializations

# %%
# construct argument parser
import argparse
ap = argparse.ArgumentParser()
ap.add_argument("-d", "--data", choices=['adult', 'compas', 'german', 'bank', 'meps19', 'grade', 'law_sex', 'law_gender_aif'], default='compas', help="dataset: adult, compas, german, bank, meps19, grade ")
ap.add_argument("-c", "--classifier", choices=['lr', 'rf', 'svm', 'nn', 'nb'], default='lr', help="baseline model: lr, rf, svm, nn, nb, dt")
ap.add_argument("-m", "--mitigator", choices=['dir', 'rew', 'egr', 'pr', 'cpp', 'ro'], required=False, help="mitigators: dir, rew, egr, pr, cpp, ro")
ap.add_argument("-b", "--bias", default=0., help="amount of bias: o-1")
ap.add_argument("-t", "--biastype", choices=['label', 'selection', 'none'], default='none', help="amount of bias: o-1")
ap.add_argument("-o", "--os", default=2, help="oversample mode: 1: privi unfav 2: unpriv fav")
# Out:
# _StoreAction(option_strings=['-o', '--os'], dest='os', nargs=None, const=None, default=2, type=None, choices=None, required=False, help='oversample mode: 1: privi unfav 2: unpriv fav', metavar=None)

# %%
import sys
sys.argv = ['']
args = vars(ap.parse_args())

# %%
args
# Out:
# {'data': 'compas',
#  'classifier': 'lr',
#  'mitigator': None,
#  'bias': 0.0,
#  'biastype': 'none',
#  'os': 2}

# %%
DATASET = "law_sex"#args["data"]
BASELINE = "dt" #args["classifier"]
MITIGATOR = args["mitigator"]
BIAS = float(args["bias"])
BIAS_TYPE = args["biastype"]
OS_MODE = int(args["os"])

# %%
# global constants
if BASELINE == 'svm' or BASELINE == 'nn':
    SCALER = False 
else:
    SCALER = False 
DISPLAY = False 
THRESH_ARR = 0.5

# loop ten times 
N = 3 

# percentage of favor and unfavor
priv_metric_orig = defaultdict(float)
favor_metric_orig = defaultdict(float)
favor_metric_transf = defaultdict(float)

# for each pre-processing approach, we create a mia_metric_results
orig_metrics = defaultdict(list)
orig_mia_metrics = defaultdict(list)

transf_metrics = defaultdict(list) 
transf_mia_metrics = defaultdict(list) 

reweigh_metrics = defaultdict(list) 
reweigh_mia_metrics = defaultdict(list) 

dir_metrics = defaultdict(list) 
dir_mia_metrics = defaultdict(list) 

egr_metrics = defaultdict(list) 
egr_mia_metrics = defaultdict(list) 


pr_orig_metrics = defaultdict(list) 
cpp_metrics = defaultdict(list) 
ro_metrics = defaultdict(list)

# %% [markdown]
# ## Loading & Splitting Dataset

# %%
# load dataset and set the groups
dataset_builder =  DatasetBuilder(DATASET)
dataset_orig = dataset_builder.load_data()
sens_attr = dataset_orig.protected_attribute_names[0]
unprivileged_groups = dataset_builder.unprivileged_groups
privileged_groups = dataset_builder.privileged_groups

# training data split ratio
p = 0.5

# %%
dataset_orig.features.shape
# Out:
# (20798, 13)

# %%
privileged_groups
# Out:
# [{'gender': 1}]

# %%
# split dataset into train, validation, and test
dataset_orig_train, dataset_orig_test = dataset_orig.split([p], shuffle=True)
dataset_orig_val = dataset_orig_test
print(dataset_orig_train.features)
# Out:
# [[ 5.  7.  0. ...  4.  6.  6.]
#  [ 6.  4.  0. ...  6.  6.  8.]
#  [ 1.  1.  0. ...  1.  2.  2.]
#  ...
#  [ 9.  9.  0. ...  5.  6.  8.]
#  [10. 10.  0. ...  3.  5.  5.]
#  [10. 10.  0. ...  5.  6.  7.]]

# %%
# NOT SUITABLE
# favorable and unfavorable labels and feature_names
f_label = dataset_orig_train.favorable_label
uf_label = dataset_orig_train.unfavorable_label
feature_names = dataset_orig_train.feature_names

# introduce label or selection biases, assuming the original data is fair
if BIAS_TYPE == 'label':
    dataset_orig_train = label_bias(dataset_orig_train, unprivileged_groups, BIAS)
elif BIAS_TYPE == 'selection':
    dataset_orig_train = selection_bias(dataset_orig_train, unprivileged_groups, BIAS)
else:
    print('no bias type specified')
# Out:
# no bias type specified

# %%
dataset_orig_train
# Out:
#                instance weights features                                  \
#
#                                  decile3 decile1 race cluster  lsat ugpa
# instance names
# 19236                       1.0      5.0     7.0  0.0     1.0  36.0  3.2
# 1837                        1.0      6.0     4.0  0.0     5.0  44.0  3.9
# 335                         1.0      1.0     1.0  0.0     6.0  22.5  2.9
# 3135                        1.0      5.0     6.0  0.0     3.0  42.0  3.4
# 3479                        1.0      5.0     3.0  0.0     4.0  42.0  3.8
# ...                         ...      ...     ...  ...     ...   ...  ...
# 16112                       1.0     10.0    10.0  0.0     4.0  46.0  3.0
# 15444                       1.0      3.0     4.0  0.0     1.0  34.0  3.5
# 10010                       1.0      9.0     9.0  0.0     4.0  42.0  3.3
# 16049                       1.0     10.0    10.0  0.0     3.0  34.0  3.2
# 4982                        1.0     10.0    10.0  0.0     4.0  42.0  3.1
#
#                                                                          \
#                                        protected attribute
#                dob_yr fulltime fam_inc              gender tier indxgrp
# instance names
# 19236            69.0      1.0     4.0                 1.0  4.0     6.0
# 1837             69.0      1.0     3.0                 1.0  6.0     6.0
# 335              59.0      1.0     3.0                 1.0  1.0     2.0
# 3135             64.0      1.0     3.0                 0.0  3.0     6.0
# 3479             70.0      1.0     3.0                 0.0  5.0     6.0
# ...               ...      ...     ...                 ...  ...     ...
# 16112            67.0      1.0     4.0                 1.0  5.0     6.0
# 15444            69.0      1.0     4.0                 1.0  4.0     6.0
# 10010            64.0      1.0     3.0                 1.0  5.0     6.0
# 16049            67.0      1.0     4.0                 0.0  3.0     5.0
# 4982             61.0      1.0     5.0                 1.0  5.0     6.0
#
#                         labels
#
#                indxgrp2
# instance names
# 19236               6.0    1.0
# 1837                8.0    1.0
# 335                 2.0    1.0
# 3135                8.0    1.0
# 3479                8.0    1.0
# ...                 ...    ...
# 16112               8.0    1.0
# 15444               6.0    1.0
# 10010               8.0    1.0
# 16049               5.0    1.0
# 4982                7.0    1.0
#
# [10399 rows x 15 columns]

# %%
dataset_orig_train?

# %% [markdown]
# ## Run Mitigating Algorithms

# %%
# run mitigating algorithms
for i in range(N):
    # split dataset into train, validation, and test
    dataset_orig_train, dataset_orig_test = dataset_orig.split([p], shuffle=True)
    dataset_orig_val = dataset_orig_test
    print("#### Train dataset's features are as below:")
    print(dataset_orig_train.features)

    # favorable and unfavorable labels and feature_names
    f_label = dataset_orig_train.favorable_label
    uf_label = dataset_orig_train.unfavorable_label
    feature_names = dataset_orig_train.feature_names

    # introduce label or selection biases, assuming the original data is fair
    if BIAS_TYPE == 'label':
        dataset_orig_train = label_bias(dataset_orig_train, unprivileged_groups, BIAS)
    elif BIAS_TYPE == 'selection':
        dataset_orig_train = selection_bias(dataset_orig_train, unprivileged_groups, BIAS)
    else:
        print('no bias type specified')

    # show data info
    print("#### Training Dataset shape")
    print(dataset_orig_train.features.shape)
    print("#### Favorable and unfavorable labels")
    print(dataset_orig_train.favorable_label, dataset_orig_train.unfavorable_label)
    print("#### Protected attribute names")
    print(dataset_orig_train.protected_attribute_names)
    print("#### Privileged and unprivileged protected groups")
    print(privileged_groups, unprivileged_groups)
    print("#### Privileged and unprivileged protected attribute values")
    print(dataset_orig_train.privileged_protected_attributes, dataset_orig_train.unprivileged_protected_attributes)
    print("#### Dataset feature names")
    print(dataset_orig_train.feature_names)

    # check fairness on the original data
    metric_orig_train = BinaryLabelDatasetMetric(dataset_orig_train, 
                                                 unprivileged_groups=unprivileged_groups,
                                                 privileged_groups=privileged_groups)
    print("privileged vs. unprivileged: ", metric_orig_train.num_positives(privileged=True) + metric_orig_train.num_negatives(privileged=True), metric_orig_train.num_positives(privileged=False) + metric_orig_train.num_negatives(privileged=False)) 
    base_rate_unprivileged = metric_orig_train.base_rate(privileged=False)
    base_rate_privileged = metric_orig_train.base_rate(privileged=True)
    print('base_pos unpriv: ', base_rate_unprivileged)
    print('base_pos priv: ', base_rate_privileged)
    print('number of favorable labels: ', np.count_nonzero(dataset_orig_train.labels==f_label))
    print("Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_orig_train.mean_difference())

    # statistics of favored/positive class BEFORE transf 
    priv_metric_orig['total_priv'] += metric_orig_train.num_instances(privileged = True) 
    priv_metric_orig['total_unpriv'] += metric_orig_train.num_instances(privileged = False) 
    favor_metric_orig['total_favor'] += metric_orig_train.base_rate()
    favor_metric_orig['total_unfavor'] += 1 - metric_orig_train.base_rate()
    favor_metric_orig['priv_favor'] += metric_orig_train.base_rate(privileged = True)
    favor_metric_orig['priv_unfavor'] += 1 - metric_orig_train.base_rate(privileged = True)
    favor_metric_orig['unpriv_favor'] += metric_orig_train.base_rate(privileged = False)
    favor_metric_orig['unpriv_unfavor'] += 1 - metric_orig_train.base_rate(privileged = False)

    print("#### Train shape, validation shape, test shape")
    print(dataset_orig_train.features.shape, dataset_orig_val.features.shape, dataset_orig_test.features.shape)

    # testing mitigation methods 
    test_cases = TestAlgorithms(BASELINE)

    # null mitigator
    orig_metrics, orig_mia_metrics = test_cases.run_original(dataset_orig_train, dataset_orig_val, dataset_orig_test, BASELINE, orig_metrics, orig_mia_metrics, f_label, uf_label, unprivileged_groups, privileged_groups, THRESH_ARR, DISPLAY, SCALER) 

    # synthetic data mitigator
    metric_transf_train, transf_metrics, transf_mia_metrics = test_cases.run_oversample(dataset_orig_train, dataset_orig_val, dataset_orig_test, privileged_groups, unprivileged_groups, base_rate_privileged, base_rate_unprivileged, BASELINE, transf_metrics, transf_mia_metrics, f_label, uf_label, THRESH_ARR, DISPLAY, OS_MODE, SCALER)
    
    # statistics of favored/positive class AFTER transf
    favor_metric_transf['total_favor'] += metric_transf_train.base_rate()
    favor_metric_transf['total_unfavor'] += 1 - metric_transf_train.base_rate()
    favor_metric_transf['priv_favor'] += metric_transf_train.base_rate(privileged = True)
    favor_metric_transf['priv_unfavor'] += 1 - metric_transf_train.base_rate(privileged = True)
    favor_metric_transf['unpriv_favor'] += metric_transf_train.base_rate(privileged = False)
    favor_metric_transf['unpriv_unfavor'] += 1 - metric_transf_train.base_rate(privileged = False)

    # dir mitigator
    dir_metrics, dir_mia_metrics = test_cases.run_dir(dataset_orig_train, dataset_orig_val, dataset_orig_test,  sens_attr, BASELINE, dir_metrics, dir_mia_metrics, f_label, uf_label, unprivileged_groups, privileged_groups, THRESH_ARR, DISPLAY, SCALER) 
    
    # reweigh mitigator
    reweigh_metrics, reweigh_mia_metrics = test_cases.run_rew(dataset_orig_train, dataset_orig_val, dataset_orig_test, f_label, uf_label,  unprivileged_groups, privileged_groups, BASELINE, reweigh_metrics, reweigh_mia_metrics, THRESH_ARR, DISPLAY, SCALER)

    # egr mitigator, in-processing
    train_test_egr, egr_metrics, egr_mia_metrics = test_cases.run_egr(dataset_orig_train, dataset_orig_val, dataset_orig_test, egr_metrics, egr_mia_metrics, BASELINE, f_label, uf_label, unprivileged_groups, privileged_groups,THRESH_ARR, DISPLAY, SCALER)
    # egr gave error so I replaced it with reweigh
#     egr_metrics, egr_mia_metrics = test_cases.run_rew(dataset_orig_train, dataset_orig_val, dataset_orig_test, f_label, uf_label,  unprivileged_groups, privileged_groups, BASELINE, egr_metrics, egr_mia_metrics, THRESH_ARR, DISPLAY, SCALER)

    # cpp mitigator
    cpp_metrics = test_cases.run_cpp(dataset_orig_train, dataset_orig_val, dataset_orig_test, cpp_metrics, BASELINE, unprivileged_groups, privileged_groups, THRESH_ARR, SCALER)

    # ro mitigator
    # ro_metrics = test_cases.run_ro(dataset_orig_train, dataset_orig_val, dataset_orig_test, ro_metrics, BASELINE, unprivileged_groups, privileged_groups, THRESH_ARR, SCALER)

    if (BASELINE == 'lr'):
        pr_orig_metrics = test_cases.run_pr(dataset_orig_train, dataset_orig_val, dataset_orig_test, pr_orig_metrics, sens_attr, f_label, uf_label, unprivileged_groups, privileged_groups, THRESH_ARR, DISPLAY, SCALER)
# Out:
# #### Train dataset's features are as below:
# [[10. 10.  0. ...  5.  6.  8.]
#  [ 2.  3.  0. ...  3.  5.  5.]
#  [ 4.  3.  0. ...  3.  4.  4.]
#  ...
#  [ 7.  6.  0. ...  3.  6.  6.]
#  [ 8.  8.  0. ...  3.  6.  6.]
#  [ 3.  4.  0. ...  4.  6.  7.]]
# no bias type specified
# #### Training Dataset shape
# (10399, 13)
# #### Favorable and unfavorable labels
# 1.0 0.0
# #### Protected attribute names
# ['gender']
# #### Privileged and unprivileged protected groups
# [{'gender': 1}] [{'gender': 0}]
# #### Privileged and unprivileged protected attribute values
# [array([1.])] [array([0.])]
# #### Dataset feature names
# ['decile3', 'decile1', 'race', 'cluster', 'lsat', 'ugpa', 'dob_yr', 'fulltime', 'fam_inc', 'gender', 'tier', 'indxgrp', 'indxgrp2']
# privileged vs. unprivileged:  5853.0 4546.0
# base_pos unpriv:  0.9408271007479102
# base_pos priv:  0.9533572526909277
# number of favorable labels:  9857
# Difference in mean outcomes between unprivileged and privileged groups = -0.012530
# #### Train shape, validation shape, test shape
# (10399, 13) (10399, 13) (10399, 13)
# #######################################################################
#                     dt
# #######################################################################
#
# ------------------------------
#
# [INFO] Original Results......
#
# ------------------------------
#
# [INFO]: training decision tree
# ####Train metrics:
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.46      0.59       542
#          1.0       0.97      0.99      0.98      9857
#
#     accuracy                           0.97     10399
#    macro avg       0.90      0.73      0.79     10399
# weighted avg       0.96      0.97      0.96     10399
#
# Train accuracy:  0.96691989614386
# Validating Original ...
# Accuracy for threshold: 0.01  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.02  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.03  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.04  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.05  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.060000000000000005  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.06999999999999999  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.08  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.09  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.09999999999999999  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.11  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.12  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.13  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.14  is: 0.9448985479373017
# Balanced accuracy is:  0.5400742450663172
# Accuracy for threshold: 0.15000000000000002  is: 0.9445138955668815
# Balanced accuracy is:  0.539872245268317
# Accuracy for threshold: 0.16  is: 0.9445138955668815
# Balanced accuracy is:  0.539872245268317
# Accuracy for threshold: 0.17  is: 0.9445138955668815
# Balanced accuracy is:  0.539872245268317
# Accuracy for threshold: 0.18000000000000002  is: 0.9445138955668815
# Balanced accuracy is:  0.539872245268317
# Accuracy for threshold: 0.19  is: 0.9445138955668815
# Balanced accuracy is:  0.539872245268317
# Accuracy for threshold: 0.2  is: 0.9441292431964612
# Balanced accuracy is:  0.5415772776998308
# Accuracy for threshold: 0.21000000000000002  is: 0.9441292431964612
# Balanced accuracy is:  0.5415772776998308
# Accuracy for threshold: 0.22  is: 0.9441292431964612
# Balanced accuracy is:  0.5415772776998308
# Accuracy for threshold: 0.23  is: 0.9441292431964612
# Balanced accuracy is:  0.5415772776998308
# Accuracy for threshold: 0.24000000000000002  is: 0.9441292431964612
# Balanced accuracy is:  0.5415772776998308
# Accuracy for threshold: 0.25  is: 0.9441292431964612
# Balanced accuracy is:  0.5415772776998308
# Accuracy for threshold: 0.26  is: 0.9441292431964612
# Balanced accuracy is:  0.5415772776998308
# Accuracy for threshold: 0.27  is: 0.9441292431964612
# Balanced accuracy is:  0.5415772776998308
# Accuracy for threshold: 0.28  is: 0.9441292431964612
# Balanced accuracy is:  0.5415772776998308
# Accuracy for threshold: 0.29000000000000004  is: 0.943936917011251
# Balanced accuracy is:  0.5443368261451016
# Accuracy for threshold: 0.3  is: 0.9423021444369651
# Balanced accuracy is:  0.5568275526101985
# Accuracy for threshold: 0.31  is: 0.9423021444369651
# Balanced accuracy is:  0.5568275526101985
# Accuracy for threshold: 0.32  is: 0.9423021444369651
# Balanced accuracy is:  0.5568275526101985
# Accuracy for threshold: 0.33  is: 0.9423021444369651
# Balanced accuracy is:  0.5568275526101985
# Accuracy for threshold: 0.34  is: 0.9418213289739398
# Balanced accuracy is:  0.5584820850922121
# Accuracy for threshold: 0.35000000000000003  is: 0.9418213289739398
# Balanced accuracy is:  0.5584820850922121
# Accuracy for threshold: 0.36000000000000004  is: 0.9418213289739398
# Balanced accuracy is:  0.5584820850922121
# Accuracy for threshold: 0.37  is: 0.9418213289739398
# Balanced accuracy is:  0.5584820850922121
# Accuracy for threshold: 0.38  is: 0.9418213289739398
# Balanced accuracy is:  0.5584820850922121
# Accuracy for threshold: 0.39  is: 0.9418213289739398
# Balanced accuracy is:  0.5584820850922121
# Accuracy for threshold: 0.4  is: 0.9416290027887297
# Balanced accuracy is:  0.559334601307969
# Accuracy for threshold: 0.41000000000000003  is: 0.9416290027887297
# Balanced accuracy is:  0.559334601307969
# Accuracy for threshold: 0.42000000000000004  is: 0.9416290027887297
# Balanced accuracy is:  0.559334601307969
# Accuracy for threshold: 0.43  is: 0.9413405135109145
# Balanced accuracy is:  0.5601366175742258
# Accuracy for threshold: 0.44  is: 0.9413405135109145
# Balanced accuracy is:  0.5601366175742258
# Accuracy for threshold: 0.45  is: 0.9416290027887297
# Balanced accuracy is:  0.5736373430293237
# Accuracy for threshold: 0.46  is: 0.9408596980478893
# Balanced accuracy is:  0.5732333434333232
# Accuracy for threshold: 0.47000000000000003  is: 0.9408596980478893
# Balanced accuracy is:  0.5732333434333232
# Accuracy for threshold: 0.48000000000000004  is: 0.9408596980478893
# Balanced accuracy is:  0.5732333434333232
# Accuracy for threshold: 0.49  is: 0.9408596980478893
# Balanced accuracy is:  0.5732333434333232
# Accuracy for threshold: 0.5  is: 0.9380709683623425
# Balanced accuracy is:  0.5765364254716067
# Best thresh:  0.5
# Best balanced accuracy: 0.5765
# Corresponding 1-min(DI, 1/DI) value: 0.9899
# Corresponding average odds difference value: -0.0407
# Corresponding statistical parity difference value: -0.0099
# Corresponding equal opportunity difference value: -0.0048
# Corresponding Theil index value: 0.0370
# Corresponding false positive_rate for privileged: 0.8611
# Corresponding false negative_rate for privileged: 0.0215
# Corresponding false positive_rate for unpribileged: 0.7846
# Corresponding false negative_rate for unprivileged: 0.0263
# Testing Original ...
# Accuracy for threshold: 0.5  is: 0.9380709683623425
# Balanced accuracy is:  0.5765364254716067
# True positive rate is:  0.9763660236339764
# True negative rate is:  0.17670682730923695
# Balanced accuracy is:  0.5765364254716067
# Test Accuracy is:  0.9380709683623425
# Best balanced accuracy: 0.5765
# Corresponding 1-min(DI, 1/DI) value: 0.9899
# Corresponding average odds difference value: -0.0407
# Corresponding statistical parity difference value: -0.0099
# Corresponding equal opportunity difference value: -0.0048
# Corresponding Theil index value: 0.0370
# Corresponding false positive_rate for privileged: 0.8611
# Corresponding false negative_rate for privileged: 0.0215
# Corresponding false positive_rate for unpribileged: 0.7846
# Corresponding false negative_rate for unprivileged: 0.0263
# Protected_attr_val, label, 0.0 0.0
# Number of training samples (ntrain): 269
# Number of test samples (ntest): 246
# Protected_attr_val, label, 0.0 1.0
# Number of training samples (ntrain): 4277
# Number of test samples (ntest): 4331
# Protected_attr_val, label, 1.0 0.0
# Number of training samples (ntrain): 273
# Number of test samples (ntest): 252
# Protected_attr_val, label, 1.0 1.0
# Number of training samples (ntrain): 5580
# Number of test samples (ntest): 5570
# MIA_Result(
#   Name: entire_dataset
#   Size of the Dataset: Train = 10399, Test = 10399
#   AUC: 0.52
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.93
#   Test Accuracy (TNR): 0.10
#   Attacker advantage: 0.03
#   Positive predictive value: 0.54
#   Optimal thershold: -0.15963014559188396
# )
# MIA_Result(
#   Name: entire_dataset_label_0.0
#   Size of the Dataset: Train = 542, Test = 498
#   AUC: 0.74
#   Privacy Risk: 0.67
#   Accuracy: 0.68
#   Train Accuracy (TPR): 0.73
#   Test Accuracy (TNR): 0.61
#   Attacker advantage: 0.34
#   Positive predictive value: 0.79
#   Optimal thershold: -1.945910149055313
# )
# MIA_Result(
#   Name: entire_dataset_label_1.0
#   Size of the Dataset: Train = 9857, Test = 9901
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.96
#   Test Accuracy (TNR): 0.06
#   Attacker advantage: 0.02
#   Positive predictive value: 0.52
#   Optimal thershold: -0.15963014559188396
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_0.0
#   Size of the Dataset: Train = 269, Test = 246
#   AUC: 0.72
#   Privacy Risk: 0.67
#   Accuracy: 0.67
#   Train Accuracy (TPR): 0.78
#   Test Accuracy (TNR): 0.56
#   Attacker advantage: 0.35
#   Positive predictive value: 0.73
#   Optimal thershold: -1.945910149055313
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_1.0
#   Size of the Dataset: Train = 4277, Test = 4331
#   AUC: 0.52
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.97
#   Test Accuracy (TNR): 0.05
#   Attacker advantage: 0.03
#   Positive predictive value: 0.52
#   Optimal thershold: -0.2876820724517809
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_0.0
#   Size of the Dataset: Train = 273, Test = 252
#   AUC: 0.75
#   Privacy Risk: 0.67
#   Accuracy: 0.67
#   Train Accuracy (TPR): 0.68
#   Test Accuracy (TNR): 0.66
#   Attacker advantage: 0.34
#   Positive predictive value: 0.87
#   Optimal thershold: -1.945910149055313
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_1.0
#   Size of the Dataset: Train = 5580, Test = 5570
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.96
#   Test Accuracy (TNR): 0.06
#   Attacker advantage: 0.02
#   Positive predictive value: 0.52
#   Optimal thershold: -0.15963014559188396
# )
#
# ------------------------------
#
# [INFO] Random Oversampling ......
#
# ------------------------------
#
# origin, transf:  10399 11620
# after transf priv:  0.9533572526909277
# after transf unpriv:  0.9533552973816543
# Difference in mean outcomes between unprivileged and privileged groups = -0.000002
# [INFO]: training decision tree
# Train metrics:
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.43      0.59       542
#          1.0       0.97      1.00      0.99     11078
#
#     accuracy                           0.97     11620
#    macro avg       0.95      0.71      0.79     11620
# weighted avg       0.97      0.97      0.97     11620
#
# Train accuracy:  0.9718588640275387
# Validating Original ...
# Accuracy for threshold: 0.01  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.02  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.03  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.04  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.05  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.060000000000000005  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.06999999999999999  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.08  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.09  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.09999999999999999  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.11  is: 0.9427829598999904
# Balanced accuracy is:  0.5456378589806149
# Accuracy for threshold: 0.12  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.13  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.14  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.15000000000000002  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.16  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.17  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.18000000000000002  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.19  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.2  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.21000000000000002  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.22  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.23  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.24000000000000002  is: 0.9424944706221752
# Balanced accuracy is:  0.5454863591321147
# Accuracy for threshold: 0.25  is: 0.9424944706221752
# Balanced accuracy is:  0.5464398752468718
# Accuracy for threshold: 0.26  is: 0.9424944706221752
# Balanced accuracy is:  0.5464398752468718
# Accuracy for threshold: 0.27  is: 0.9424944706221752
# Balanced accuracy is:  0.5464398752468718
# Accuracy for threshold: 0.28  is: 0.9424944706221752
# Balanced accuracy is:  0.5464398752468718
# Accuracy for threshold: 0.29000000000000004  is: 0.9424944706221752
# Balanced accuracy is:  0.5464398752468718
# Accuracy for threshold: 0.3  is: 0.9424944706221752
# Balanced accuracy is:  0.5464398752468718
# Accuracy for threshold: 0.31  is: 0.9424944706221752
# Balanced accuracy is:  0.5464398752468718
# Accuracy for threshold: 0.32  is: 0.9424944706221752
# Balanced accuracy is:  0.5464398752468718
# Accuracy for threshold: 0.33  is: 0.9424944706221752
# Balanced accuracy is:  0.5464398752468718
# Accuracy for threshold: 0.34  is: 0.9422059813443601
# Balanced accuracy is:  0.5462883753983716
# Accuracy for threshold: 0.35000000000000003  is: 0.9422059813443601
# Balanced accuracy is:  0.5462883753983716
# Accuracy for threshold: 0.36000000000000004  is: 0.9422059813443601
# Balanced accuracy is:  0.5462883753983716
# Accuracy for threshold: 0.37  is: 0.9422059813443601
# Balanced accuracy is:  0.5462883753983716
# Accuracy for threshold: 0.38  is: 0.9422059813443601
# Balanced accuracy is:  0.5462883753983716
# Accuracy for threshold: 0.39  is: 0.9423983075295701
# Balanced accuracy is:  0.5540175042154275
# Accuracy for threshold: 0.4  is: 0.9423983075295701
# Balanced accuracy is:  0.5540175042154275
# Accuracy for threshold: 0.41000000000000003  is: 0.9423983075295701
# Balanced accuracy is:  0.5540175042154275
# Accuracy for threshold: 0.42000000000000004  is: 0.9423983075295701
# Balanced accuracy is:  0.5540175042154275
# Accuracy for threshold: 0.43  is: 0.9423983075295701
# Balanced accuracy is:  0.5540175042154275
# Accuracy for threshold: 0.44  is: 0.9423983075295701
# Balanced accuracy is:  0.5540175042154275
# Accuracy for threshold: 0.45  is: 0.9425906337147802
# Balanced accuracy is:  0.5569790524586985
# Accuracy for threshold: 0.46  is: 0.9425906337147802
# Balanced accuracy is:  0.5569790524586985
# Accuracy for threshold: 0.47000000000000003  is: 0.9425906337147802
# Balanced accuracy is:  0.5569790524586985
# Accuracy for threshold: 0.48000000000000004  is: 0.9425906337147802
# Balanced accuracy is:  0.5569790524586985
# Accuracy for threshold: 0.49  is: 0.9425906337147802
# Balanced accuracy is:  0.5569790524586985
# Accuracy for threshold: 0.5  is: 0.9423021444369651
# Balanced accuracy is:  0.5606416170692263
# Best thresh:  0.5
# Best balanced accuracy: 0.5606
# Corresponding 1-min(DI, 1/DI) value: 0.9943
# Corresponding average odds difference value: -0.0096
# Corresponding statistical parity difference value: -0.0056
# Corresponding equal opportunity difference value: -0.0038
# Corresponding Theil index value: 0.0313
# Corresponding false positive_rate for privileged: 0.8690
# Corresponding false negative_rate for privileged: 0.0156
# Corresponding false positive_rate for unpribileged: 0.8537
# Corresponding false negative_rate for unprivileged: 0.0194
# Testing Original ...
# Accuracy for threshold: 0.5  is: 0.9423021444369651
# Balanced accuracy is:  0.5606416170692263
# True positive rate is:  0.9827290172709827
# True negative rate is:  0.13855421686746988
# Balanced accuracy is:  0.5606416170692263
# Test Accuracy is:  0.9423021444369651
# Best balanced accuracy: 0.5606
# Corresponding 1-min(DI, 1/DI) value: 0.9943
# Corresponding average odds difference value: -0.0096
# Corresponding statistical parity difference value: -0.0056
# Corresponding equal opportunity difference value: -0.0038
# Corresponding Theil index value: 0.0313
# Corresponding false positive_rate for privileged: 0.8690
# Corresponding false negative_rate for privileged: 0.0156
# Corresponding false positive_rate for unpribileged: 0.8537
# Corresponding false negative_rate for unprivileged: 0.0194
# Protected_attr_val, label, 0.0 0.0
# Number of training samples (ntrain): 269
# Number of test samples (ntest): 246
# Protected_attr_val, label, 0.0 1.0
# Number of training samples (ntrain): 4277
# Number of test samples (ntest): 4331
# Protected_attr_val, label, 1.0 0.0
# Number of training samples (ntrain): 273
# Number of test samples (ntest): 252
# Protected_attr_val, label, 1.0 1.0
# Number of training samples (ntrain): 5580
# Number of test samples (ntest): 5570
# MIA_Result(
#   Name: entire_dataset
#   Size of the Dataset: Train = 10399, Test = 10399
#   AUC: 0.52
#   Privacy Risk: 0.52
#   Accuracy: 0.52
#   Train Accuracy (TPR): 0.99
#   Test Accuracy (TNR): 0.05
#   Attacker advantage: 0.03
#   Positive predictive value: 0.54
#   Optimal thershold: -2.1400661634962708
# )
# MIA_Result(
#   Name: entire_dataset_label_0.0
#   Size of the Dataset: Train = 542, Test = 498
#   AUC: 0.77
#   Privacy Risk: 0.71
#   Accuracy: 0.71
#   Train Accuracy (TPR): 0.73
#   Test Accuracy (TNR): 0.70
#   Attacker advantage: 0.43
#   Positive predictive value: 0.80
#   Optimal thershold: -2.1400661634962708
# )
# MIA_Result(
#   Name: entire_dataset_label_1.0
#   Size of the Dataset: Train = 9857, Test = 9901
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.99
#   Test Accuracy (TNR): 0.03
#   Attacker advantage: 0.02
#   Positive predictive value: 0.52
#   Optimal thershold: -0.2876820724517809
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_0.0
#   Size of the Dataset: Train = 269, Test = 246
#   AUC: 0.78
#   Privacy Risk: 0.73
#   Accuracy: 0.73
#   Train Accuracy (TPR): 0.73
#   Test Accuracy (TNR): 0.73
#   Attacker advantage: 0.46
#   Positive predictive value: 0.82
#   Optimal thershold: -2.1400661634962708
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_1.0
#   Size of the Dataset: Train = 4277, Test = 4331
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.94
#   Test Accuracy (TNR): 0.09
#   Attacker advantage: 0.03
#   Positive predictive value: 0.51
#   Optimal thershold: -0.10536051565782628
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_0.0
#   Size of the Dataset: Train = 273, Test = 252
#   AUC: 0.76
#   Privacy Risk: 0.70
#   Accuracy: 0.70
#   Train Accuracy (TPR): 0.72
#   Test Accuracy (TNR): 0.67
#   Attacker advantage: 0.40
#   Positive predictive value: 0.77
#   Optimal thershold: -2.197224577336219
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_1.0
#   Size of the Dataset: Train = 5580, Test = 5570
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.99
#   Test Accuracy (TNR): 0.03
#   Attacker advantage: 0.02
#   Positive predictive value: 0.53
#   Optimal thershold: -0.2876820724517809
# )
#
# ------------------------------
#
# [INFO] preprocessing--disparat impact remover ......
#
# ------------------------------
#
# [INFO]: training decision tree
# ####Train metrics:
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.44      0.59       542
#          1.0       0.97      1.00      0.98      9857
#
#     accuracy                           0.97     10399
#    macro avg       0.92      0.72      0.79     10399
# weighted avg       0.97      0.97      0.96     10399
#
# Train accuracy:  0.9676892008847005
# Validating Original ...
# Accuracy for threshold: 0.01  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.02  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.03  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.04  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.05  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.060000000000000005  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.06999999999999999  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.08  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.09  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.09999999999999999  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.11  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.12  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.13  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.14  is: 0.9453793634003269
# Balanced accuracy is:  0.556536518764686
# Accuracy for threshold: 0.15000000000000002  is: 0.9443215693816713
# Balanced accuracy is:  0.5607485998939704
# Accuracy for threshold: 0.16  is: 0.9443215693816713
# Balanced accuracy is:  0.5607485998939704
# Accuracy for threshold: 0.17  is: 0.9443215693816713
# Balanced accuracy is:  0.5607485998939704
# Accuracy for threshold: 0.18000000000000002  is: 0.9443215693816713
# Balanced accuracy is:  0.5607485998939704
# Accuracy for threshold: 0.19  is: 0.9443215693816713
# Balanced accuracy is:  0.5607485998939704
# Accuracy for threshold: 0.2  is: 0.9441292431964612
# Balanced accuracy is:  0.5606475999949703
# Accuracy for threshold: 0.21000000000000002  is: 0.9441292431964612
# Balanced accuracy is:  0.5606475999949703
# Accuracy for threshold: 0.22  is: 0.9441292431964612
# Balanced accuracy is:  0.5606475999949703
# Accuracy for threshold: 0.23  is: 0.9441292431964612
# Balanced accuracy is:  0.5606475999949703
# Accuracy for threshold: 0.24000000000000002  is: 0.9441292431964612
# Balanced accuracy is:  0.5606475999949703
# Accuracy for threshold: 0.25  is: 0.943744590826041
# Balanced accuracy is:  0.5604456001969701
# Accuracy for threshold: 0.26  is: 0.943744590826041
# Balanced accuracy is:  0.5604456001969701
# Accuracy for threshold: 0.27  is: 0.943744590826041
# Balanced accuracy is:  0.5604456001969701
# Accuracy for threshold: 0.28  is: 0.943744590826041
# Balanced accuracy is:  0.5604456001969701
# Accuracy for threshold: 0.29000000000000004  is: 0.943744590826041
# Balanced accuracy is:  0.5604456001969701
# Accuracy for threshold: 0.3  is: 0.9426867968073853
# Balanced accuracy is:  0.5646576813262544
# Accuracy for threshold: 0.31  is: 0.9426867968073853
# Balanced accuracy is:  0.5646576813262544
# Accuracy for threshold: 0.32  is: 0.9426867968073853
# Balanced accuracy is:  0.5646576813262544
# Accuracy for threshold: 0.33  is: 0.9426867968073853
# Balanced accuracy is:  0.5646576813262544
# Accuracy for threshold: 0.34  is: 0.9420136551591499
# Balanced accuracy is:  0.567164730024025
# Accuracy for threshold: 0.35000000000000003  is: 0.9420136551591499
# Balanced accuracy is:  0.567164730024025
# Accuracy for threshold: 0.36000000000000004  is: 0.9420136551591499
# Balanced accuracy is:  0.567164730024025
# Accuracy for threshold: 0.37  is: 0.9420136551591499
# Balanced accuracy is:  0.567164730024025
# Accuracy for threshold: 0.38  is: 0.9420136551591499
# Balanced accuracy is:  0.567164730024025
# Accuracy for threshold: 0.39  is: 0.9420136551591499
# Balanced accuracy is:  0.567164730024025
# Accuracy for threshold: 0.4  is: 0.9416290027887297
# Balanced accuracy is:  0.5669627302260247
# Accuracy for threshold: 0.41000000000000003  is: 0.9416290027887297
# Balanced accuracy is:  0.5669627302260247
# Accuracy for threshold: 0.42000000000000004  is: 0.9416290027887297
# Balanced accuracy is:  0.5669627302260247
# Accuracy for threshold: 0.43  is: 0.9416290027887297
# Balanced accuracy is:  0.5669627302260247
# Accuracy for threshold: 0.44  is: 0.9416290027887297
# Balanced accuracy is:  0.5669627302260247
# Accuracy for threshold: 0.45  is: 0.9416290027887297
# Balanced accuracy is:  0.5679162463407817
# Accuracy for threshold: 0.46  is: 0.9416290027887297
# Balanced accuracy is:  0.5679162463407817
# Accuracy for threshold: 0.47000000000000003  is: 0.9406673718626791
# Balanced accuracy is:  0.5674112468457813
# Accuracy for threshold: 0.48000000000000004  is: 0.9406673718626791
# Balanced accuracy is:  0.5674112468457813
# Accuracy for threshold: 0.49  is: 0.9406673718626791
# Balanced accuracy is:  0.5674112468457813
# Accuracy for threshold: 0.5  is: 0.9416290027887297
# Balanced accuracy is:  0.5850795364064073
# Best thresh:  0.5
# Best balanced accuracy: 0.5851
# Corresponding 1-min(DI, 1/DI) value: 0.9906
# Corresponding average odds difference value: -0.0423
# Corresponding statistical parity difference value: -0.0091
# Corresponding equal opportunity difference value: -0.0036
# Corresponding Theil index value: 0.0338
# Corresponding false positive_rate for privileged: 0.8492
# Corresponding false negative_rate for privileged: 0.0190
# Corresponding false positive_rate for unpribileged: 0.7683
# Corresponding false negative_rate for unprivileged: 0.0226
# Testing Original ...
# Accuracy for threshold: 0.5  is: 0.9416290027887297
# Balanced accuracy is:  0.5850795364064073
# True positive rate is:  0.9793960206039793
# True negative rate is:  0.19076305220883535
# Balanced accuracy is:  0.5850795364064073
# Test Accuracy is:  0.9416290027887297
# Best balanced accuracy: 0.5851
# Corresponding 1-min(DI, 1/DI) value: 0.9906
# Corresponding average odds difference value: -0.0423
# Corresponding statistical parity difference value: -0.0091
# Corresponding equal opportunity difference value: -0.0036
# Corresponding Theil index value: 0.0338
# Corresponding false positive_rate for privileged: 0.8492
# Corresponding false negative_rate for privileged: 0.0190
# Corresponding false positive_rate for unpribileged: 0.7683
# Corresponding false negative_rate for unprivileged: 0.0226
# Protected_attr_val, label, 0.0 0.0
# Number of training samples (ntrain): 269
# Number of test samples (ntest): 246
# Protected_attr_val, label, 0.0 1.0
# Number of training samples (ntrain): 4277
# Number of test samples (ntest): 4331
# Protected_attr_val, label, 1.0 0.0
# Number of training samples (ntrain): 273
# Number of test samples (ntest): 252
# Protected_attr_val, label, 1.0 1.0
# Number of training samples (ntrain): 5580
# Number of test samples (ntest): 5570
# MIA_Result(
#   Name: entire_dataset
#   Size of the Dataset: Train = 10399, Test = 10399
#   AUC: 0.52
#   Privacy Risk: 0.52
#   Accuracy: 0.52
#   Train Accuracy (TPR): 0.95
#   Test Accuracy (TNR): 0.08
#   Attacker advantage: 0.03
#   Positive predictive value: 0.51
#   Optimal thershold: -0.2933478099874583
# )
# MIA_Result(
#   Name: entire_dataset_label_0.0
#   Size of the Dataset: Train = 542, Test = 498
#   AUC: 0.71
#   Privacy Risk: 0.66
#   Accuracy: 0.65
#   Train Accuracy (TPR): 0.55
#   Test Accuracy (TNR): 0.76
#   Attacker advantage: 0.32
#   Positive predictive value: 0.75
#   Optimal thershold: -1.1631508098056809
# )
# MIA_Result(
#   Name: entire_dataset_label_1.0
#   Size of the Dataset: Train = 9857, Test = 9901
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.98
#   Test Accuracy (TNR): 0.04
#   Attacker advantage: 0.02
#   Positive predictive value: 0.51
#   Optimal thershold: -0.2933478099874583
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_0.0
#   Size of the Dataset: Train = 269, Test = 246
#   AUC: 0.70
#   Privacy Risk: 0.66
#   Accuracy: 0.66
#   Train Accuracy (TPR): 0.57
#   Test Accuracy (TNR): 0.76
#   Attacker advantage: 0.33
#   Positive predictive value: 0.72
#   Optimal thershold: -1.1631508098056809
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_1.0
#   Size of the Dataset: Train = 4277, Test = 4331
#   AUC: 0.51
#   Privacy Risk: 0.52
#   Accuracy: 0.52
#   Train Accuracy (TPR): 0.66
#   Test Accuracy (TNR): 0.37
#   Attacker advantage: 0.03
#   Positive predictive value: 0.51
#   Optimal thershold: -0.008583743691391442
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_0.0
#   Size of the Dataset: Train = 273, Test = 252
#   AUC: 0.73
#   Privacy Risk: 0.66
#   Accuracy: 0.66
#   Train Accuracy (TPR): 0.67
#   Test Accuracy (TNR): 0.65
#   Attacker advantage: 0.33
#   Positive predictive value: 0.80
#   Optimal thershold: -1.945910149055313
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_1.0
#   Size of the Dataset: Train = 5580, Test = 5570
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.96
#   Test Accuracy (TNR): 0.05
#   Attacker advantage: 0.02
#   Positive predictive value: 0.51
#   Optimal thershold: -0.1823215567939546
# )
#
# ------------------------------
#
# [INFO] preprocessing--reweighting ......
#
# ------------------------------
#
# [INFO]: training decision tree
# ####Train metrics:
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.44      0.59       542
#          1.0       0.97      1.00      0.98      9857
#
#     accuracy                           0.97     10399
#    macro avg       0.94      0.72      0.79     10399
# weighted avg       0.97      0.97      0.96     10399
#
# Train accuracy:  0.9682661794403308
# Validating Original ...
# Accuracy for threshold: 0.01  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.02  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.03  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.04  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.05  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.060000000000000005  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.06999999999999999  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.08  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.09  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.09999999999999999  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.11  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.12  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.13  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.14  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.15000000000000002  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.16  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.17  is: 0.9423983075295701
# Balanced accuracy is:  0.5463893752973716
# Accuracy for threshold: 0.18000000000000002  is: 0.9419174920665448
# Balanced accuracy is:  0.5480439077793854
# Accuracy for threshold: 0.19  is: 0.9419174920665448
# Balanced accuracy is:  0.5480439077793854
# Accuracy for threshold: 0.2  is: 0.9416290027887297
# Balanced accuracy is:  0.5488459240456423
# Accuracy for threshold: 0.21000000000000002  is: 0.9413405135109145
# Balanced accuracy is:  0.5486944241971421
# Accuracy for threshold: 0.22  is: 0.9413405135109145
# Balanced accuracy is:  0.5486944241971421
# Accuracy for threshold: 0.23  is: 0.9413405135109145
# Balanced accuracy is:  0.5486944241971421
# Accuracy for threshold: 0.24000000000000002  is: 0.9413405135109145
# Balanced accuracy is:  0.5486944241971421
# Accuracy for threshold: 0.25  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.26  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.27  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.28  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.29000000000000004  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.3  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.31  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.32  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.33  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.34  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.35000000000000003  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.36000000000000004  is: 0.9413405135109145
# Balanced accuracy is:  0.549647940311899
# Accuracy for threshold: 0.37  is: 0.9412443504183095
# Balanced accuracy is:  0.5515044725919129
# Accuracy for threshold: 0.38  is: 0.9412443504183095
# Balanced accuracy is:  0.5515044725919129
# Accuracy for threshold: 0.39  is: 0.9408596980478893
# Balanced accuracy is:  0.5579770855972116
# Accuracy for threshold: 0.4  is: 0.9408596980478893
# Balanced accuracy is:  0.5579770855972116
# Accuracy for threshold: 0.41000000000000003  is: 0.9411481873257044
# Balanced accuracy is:  0.5714778110523094
# Accuracy for threshold: 0.42000000000000004  is: 0.940571208770074
# Balanced accuracy is:  0.5711748113553091
# Accuracy for threshold: 0.43  is: 0.940571208770074
# Balanced accuracy is:  0.5711748113553091
# Accuracy for threshold: 0.44  is: 0.940571208770074
# Balanced accuracy is:  0.5711748113553091
# Accuracy for threshold: 0.45  is: 0.940571208770074
# Balanced accuracy is:  0.5711748113553091
# Accuracy for threshold: 0.46  is: 0.940571208770074
# Balanced accuracy is:  0.5711748113553091
# Accuracy for threshold: 0.47000000000000003  is: 0.940571208770074
# Balanced accuracy is:  0.5711748113553091
# Accuracy for threshold: 0.48000000000000004  is: 0.9395134147514184
# Balanced accuracy is:  0.5706193119108085
# Accuracy for threshold: 0.49  is: 0.9395134147514184
# Balanced accuracy is:  0.5706193119108085
# Accuracy for threshold: 0.5  is: 0.9395134147514184
# Balanced accuracy is:  0.5706193119108085
# Best thresh:  0.41000000000000003
# Best balanced accuracy: 0.5706
# Corresponding 1-min(DI, 1/DI) value: 0.9956
# Corresponding average odds difference value: -0.0205
# Corresponding statistical parity difference value: -0.0043
# Corresponding equal opportunity difference value: -0.0009
# Corresponding Theil index value: 0.0350
# Corresponding false positive_rate for privileged: 0.8571
# Corresponding false negative_rate for privileged: 0.0210
# Corresponding false positive_rate for unpribileged: 0.8171
# Corresponding false negative_rate for unprivileged: 0.0219
# Testing Original ...
# Accuracy for threshold: 0.41000000000000003  is: 0.9411481873257044
# Balanced accuracy is:  0.5714778110523094
# True positive rate is:  0.9803050196949803
# True negative rate is:  0.16265060240963855
# Balanced accuracy is:  0.5714778110523094
# Test Accuracy is:  0.9411481873257044
# Best balanced accuracy: 0.5715
# Corresponding 1-min(DI, 1/DI) value: 0.9942
# Corresponding average odds difference value: -0.0212
# Corresponding statistical parity difference value: -0.0057
# Corresponding equal opportunity difference value: -0.0023
# Corresponding Theil index value: 0.0333
# Corresponding false positive_rate for privileged: 0.8571
# Corresponding false negative_rate for privileged: 0.0187
# Corresponding false positive_rate for unpribileged: 0.8171
# Corresponding false negative_rate for unprivileged: 0.0210
# Protected_attr_val, label, 0.0 0.0
# Number of training samples (ntrain): 269
# Number of test samples (ntest): 246
# Protected_attr_val, label, 0.0 1.0
# Number of training samples (ntrain): 4277
# Number of test samples (ntest): 4331
# Protected_attr_val, label, 1.0 0.0
# Number of training samples (ntrain): 273
# Number of test samples (ntest): 252
# Protected_attr_val, label, 1.0 1.0
# Number of training samples (ntrain): 5580
# Number of test samples (ntest): 5570
# MIA_Result(
#   Name: entire_dataset
#   Size of the Dataset: Train = 10399, Test = 10399
#   AUC: 0.52
#   Privacy Risk: 0.52
#   Accuracy: 0.52
#   Train Accuracy (TPR): 0.93
#   Test Accuracy (TNR): 0.10
#   Attacker advantage: 0.03
#   Positive predictive value: 0.55
#   Optimal thershold: -0.16132779701697195
# )
# MIA_Result(
#   Name: entire_dataset_label_0.0
#   Size of the Dataset: Train = 542, Test = 498
#   AUC: 0.73
#   Privacy Risk: 0.67
#   Accuracy: 0.66
#   Train Accuracy (TPR): 0.53
#   Test Accuracy (TNR): 0.81
#   Attacker advantage: 0.34
#   Positive predictive value: 0.78
#   Optimal thershold: -1.0997782011281236
# )
# MIA_Result(
#   Name: entire_dataset_label_1.0
#   Size of the Dataset: Train = 9857, Test = 9901
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.96
#   Test Accuracy (TNR): 0.06
#   Attacker advantage: 0.03
#   Positive predictive value: 0.53
#   Optimal thershold: -0.16132779701697195
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_0.0
#   Size of the Dataset: Train = 269, Test = 246
#   AUC: 0.73
#   Privacy Risk: 0.68
#   Accuracy: 0.68
#   Train Accuracy (TPR): 0.67
#   Test Accuracy (TNR): 0.69
#   Attacker advantage: 0.36
#   Positive predictive value: 0.77
#   Optimal thershold: -1.3859500582374427
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_1.0
#   Size of the Dataset: Train = 4277, Test = 4331
#   AUC: 0.51
#   Privacy Risk: 0.52
#   Accuracy: 0.52
#   Train Accuracy (TPR): 0.97
#   Test Accuracy (TNR): 0.06
#   Attacker advantage: 0.03
#   Positive predictive value: 0.53
#   Optimal thershold: -0.16132779701697195
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_0.0
#   Size of the Dataset: Train = 273, Test = 252
#   AUC: 0.74
#   Privacy Risk: 0.67
#   Accuracy: 0.67
#   Train Accuracy (TPR): 0.52
#   Test Accuracy (TNR): 0.82
#   Attacker advantage: 0.34
#   Positive predictive value: 0.80
#   Optimal thershold: -1.0997782011281236
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_1.0
#   Size of the Dataset: Train = 5580, Test = 5570
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.95
#   Test Accuracy (TNR): 0.07
#   Attacker advantage: 0.02
#   Positive predictive value: 0.53
#   Optimal thershold: -0.15421627799840534
# )
#
# ------------------------------
#
#
# [INFO:] in-processing Exponentiation Gradient Reduction ......
#
#
# ------------------------------
#
# Fitting ExponentiatedGradient ...
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\fairlearn\reductions\_moments\utility_parity.py:214: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.pos_basis[i]["+", e, g] = 1
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\fairlearn\reductions\_moments\utility_parity.py:215: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.neg_basis[i]["-", e, g] = 1
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\fairlearn\reductions\_moments\utility_parity.py:214: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.pos_basis[i]["+", e, g] = 1
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\fairlearn\reductions\_moments\utility_parity.py:215: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.neg_basis[i]["-", e, g] = 1
# Done fitting
# Accuracy for threshold: 0.01  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.02  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.03  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.04  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.05  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.060000000000000005  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.06999999999999999  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.08  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.09  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.09999999999999999  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.11  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.12  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.13  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.14  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.15000000000000002  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.16  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.17  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.18000000000000002  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.19  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.2  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.21000000000000002  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.22  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.23  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.24000000000000002  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.25  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.26  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.27  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.28  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.29000000000000004  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.3  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.31  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.32  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.33  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.34  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.35000000000000003  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.36000000000000004  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.37  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.38  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.39  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.4  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.41000000000000003  is: 0.06981440523127223
# Balanced accuracy is:  0.3923244741413893
# Accuracy for threshold: 0.42000000000000004  is: 0.05981344360034619
# Balanced accuracy is:  0.42902718844269105
# Accuracy for threshold: 0.43  is: 0.05981344360034619
# Balanced accuracy is:  0.42902718844269105
# Accuracy for threshold: 0.44  is: 0.05981344360034619
# Balanced accuracy is:  0.42902718844269105
# Accuracy for threshold: 0.45  is: 0.05981344360034619
# Balanced accuracy is:  0.42902718844269105
# Accuracy for threshold: 0.46  is: 0.05981344360034619
# Balanced accuracy is:  0.42902718844269105
# Accuracy for threshold: 0.47000000000000003  is: 0.05981344360034619
# Balanced accuracy is:  0.42902718844269105
# Accuracy for threshold: 0.48000000000000004  is: 0.05981344360034619
# ...
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.46      0.63       263
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.46       263
#    macro avg       0.50      0.23      0.32       263
# weighted avg       1.00      0.46      0.63       263
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      1.00      1.00      5627
#
#     accuracy                           1.00      5627
#    macro avg       0.50      0.50      0.50      5627
# weighted avg       1.00      1.00      1.00      5627
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.17      0.30       248
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.17       248
#    macro avg       0.50      0.09      0.15       248
# weighted avg       1.00      0.17      0.30       248
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.98      0.99      4366
#
#     accuracy                           0.98      4366
#    macro avg       0.50      0.49      0.49      4366
# weighted avg       1.00      0.98      0.99      4366
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.13      0.22       262
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.13       262
#    macro avg       0.50      0.06      0.11       262
# weighted avg       1.00      0.13      0.22       262
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.98      0.99      5523
#
#     accuracy                           0.98      5523
#    macro avg       0.50      0.49      0.50      5523
# weighted avg       1.00      0.98      0.99      5523
#
# Protected_attr_val, label, 0.0 0.0
# Number of training samples (ntrain): 267
# Number of test samples (ntest): 248
# Protected_attr_val, label, 0.0 1.0
# Number of training samples (ntrain): 4242
# Number of test samples (ntest): 4366
# Protected_attr_val, label, 1.0 0.0
# Number of training samples (ntrain): 263
# Number of test samples (ntest): 262
# Protected_attr_val, label, 1.0 1.0
# Number of training samples (ntrain): 5627
# Number of test samples (ntest): 5523
# MIA_Result(
#   Name: entire_dataset
#   Size of the Dataset: Train = 10399, Test = 10399
#   AUC: 0.52
#   Privacy Risk: 0.52
#   Accuracy: 0.52
#   Train Accuracy (TPR): 0.98
#   Test Accuracy (TNR): 0.06
#   Attacker advantage: 0.04
#   Positive predictive value: 0.51
#   Optimal thershold: -3.3977396382823635
# )
# MIA_Result(
#   Name: entire_dataset_label_0.0
#   Size of the Dataset: Train = 530, Test = 510
#   AUC: 0.70
#   Privacy Risk: 0.69
#   Accuracy: 0.69
#   Train Accuracy (TPR): 0.60
#   Test Accuracy (TNR): 0.77
#   Attacker advantage: 0.38
#   Positive predictive value: 0.81
#   Optimal thershold: -3.3977396382823635
# )
# MIA_Result(
#   Name: entire_dataset_label_1.0
#   Size of the Dataset: Train = 9869, Test = 9889
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 0.99
#   Test Accuracy (TNR): 0.04
#   Attacker advantage: 0.03
#   Positive predictive value: 0.51
#   Optimal thershold: -9.992007221626415e-16
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_0.0
#   Size of the Dataset: Train = 267, Test = 248
#   AUC: 0.66
#   Privacy Risk: 0.66
#   Accuracy: 0.66
#   Train Accuracy (TPR): 0.50
#   Test Accuracy (TNR): 0.82
#   Attacker advantage: 0.32
#   Positive predictive value: 0.75
#   Optimal thershold: -0.03402099771495534
# )
# MIA_Result(
#   Name: subpopulation_0.0_label_1.0
#   Size of the Dataset: Train = 4242, Test = 4366
#   AUC: 0.51
#   Privacy Risk: 0.51
#   Accuracy: 0.51
#   Train Accuracy (TPR): 1.00
#   Test Accuracy (TNR): 0.02
#   Attacker advantage: 0.02
#   Positive predictive value: 0.50
#   Optimal thershold: -9.992007221626415e-16
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_0.0
#   Size of the Dataset: Train = 263, Test = 262
#   AUC: 0.74
#   Privacy Risk: 0.72
#   Accuracy: 0.72
#   Train Accuracy (TPR): 0.71
#   Test Accuracy (TNR): 0.73
#   Attacker advantage: 0.44
#   Positive predictive value: 0.81
#   Optimal thershold: -3.3977396382823635
# )
# MIA_Result(
#   Name: subpopulation_1.0_label_1.0
#   Size of the Dataset: Train = 5627, Test = 5523
#   AUC: 0.52
#   Privacy Risk: 0.52
#   Accuracy: 0.52
#   Train Accuracy (TPR): 0.98
#   Test Accuracy (TNR): 0.05
#   Attacker advantage: 0.04
#   Positive predictive value: 0.51
#   Optimal thershold: -9.992007221626415e-16
# )
#
# ------------------------------
#
#
# [INFO:] post-processing Calibrated Equal Odds ......
#
#
# ------------------------------
#
# Best balanced accuracy: 0.5499
# Corresponding 1-min(DI, 1/DI) value: 0.9705
# Corresponding average odds difference value: -0.1016
# Corresponding statistical parity difference value: -0.0294
# Corresponding equal opportunity difference value: -0.0205
# Corresponding Theil index value: 0.0268
# Corresponding false positive_rate for privileged: 0.9771
# Corresponding false negative_rate for privileged: 0.0029
# Corresponding false positive_rate for unpribileged: 0.7944
# Corresponding false negative_rate for unprivileged: 0.0234

# %%
import pandas as pd
df_converted, _ = dataset_orig.convert_to_dataframe()
df_converted['gender'].value_counts()
# Out:
# gender
# 1.0    11675
# 0.0     9123
# Name: count, dtype: int64

# %%
counts_ = df_converted['gender'].value_counts()

# %%
# %matplotlib inline

# %%
# Plot the bar graph
plt.figure(figsize=(6, 4))
counts_.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Count of Privileged and Unprivileged Values in Gender')
plt.xlabel('Gender Category (1=Privileged, 0=Unprivileged)')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
df_converted.shape
# Out:
# (20798, 14)

# %%
# Count the occurrences of privileged and unprivileged values
label_counts = df_converted['pass_bar'].value_counts()

# Plot the bar graph
plt.figure(figsize=(6, 4))
counts_.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Count of Favorable and Unfavorable Values in Dataset')
plt.xlabel('Label Category (1=Favorable, 0=Unfavorable)')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Display Output

# %%
priv_metric_orig_copy = priv_metric_orig

# %%
priv_metric_orig_copy
# Out:
# defaultdict(float, {'total_priv': 17633.0, 'total_unpriv': 13564.0})

# %%
priv_metric_orig
# Out:
# defaultdict(float, {'total_priv': 17633.0, 'total_unpriv': 13564.0})

# %%
priv_metric_orig = priv_metric_orig_copy

# %%
# %matplotlib inline
print('1)\n')
print(DATASET)
print(dataset_orig_train.features.shape[0])

print('2)\n')
priv_metric_orig = {k: [v/N] for (k,v) in priv_metric_orig.items()}
results = [priv_metric_orig]
tr = pd.Series(['orig'], name='num_instance')
df = pd.concat([pd.DataFrame(metrics) for metrics in results], axis = 0).set_index([tr])
print(df)

print('3)\n')
favor_metric_orig = {k: [v/N] for (k,v) in favor_metric_orig.items()}
favor_metric_transf = {k: [v/N] for (k,v) in favor_metric_transf.items()}
pd.set_option('display.multi_sparse', False)
results = [favor_metric_orig, favor_metric_transf]
tr = pd.Series(['orig'] + ['transf'], name='dataset')
df = pd.concat([pd.DataFrame(metrics) for metrics in results], axis = 0).set_index([tr])
print(df)

print('4)\n')
# dataframe to display fairness metrics
# error metrics
orig_error_metrics = {k: [statistics.stdev(v)] for (k,v) in orig_metrics.items()}
transf_error_metrics = {k: [statistics.stdev(v)] for (k,v) in transf_metrics.items()}
reweigh_error_metrics = {k: [statistics.stdev(v)] for (k,v) in reweigh_metrics.items()}
dir_error_metrics = {k: [statistics.stdev(v)] for (k,v) in dir_metrics.items()}
egr_error_metrics = {k: [statistics.stdev(v)] for (k,v) in egr_metrics.items()}
pr_orig_error_metrics = {k: [statistics.stdev(v)] for (k,v) in pr_orig_metrics.items()}
cpp_error_metrics = {k: [statistics.stdev(v)] for (k,v) in cpp_metrics.items()}
ro_error_metrics = {k: [statistics.stdev(v)] for (k,v) in ro_metrics.items()}

# mean value metrics
orig_metrics_mean = {k: [sum(v)/N] for (k,v) in orig_metrics.items()}
transf_metrics_mean = {k: [sum(v)/N] for (k,v) in transf_metrics.items()}
reweigh_metrics_mean = {k:[sum(v)/N] for (k,v) in reweigh_metrics.items()}
dir_metrics_mean = {k:[sum(v)/N] for (k,v) in dir_metrics.items()}
egr_metrics_mean = {k:[sum(v)/N] for (k,v) in egr_metrics.items()}
pr_orig_metrics_mean = {k: [sum(v)/N] for (k,v) in pr_orig_metrics.items()}
cpp_metrics_mean = {k: [sum(v)/N] for (k,v) in cpp_metrics.items()}
ro_metrics_mean = {k: [sum(v)/N] for (k,v) in ro_metrics.items()}

# Python paired sample t-test
from scipy.stats import ttest_rel
def paired_t (a, b):
    np_a = np.array(a)
    np_b = np.array(b)
    s, p = ttest_rel(np.absolute(np_a), np.absolute(np_b))
    return p

def acc_diff (a, b):
    np_a = np.array(a)
    np_b = np.array(b)
    delta = np_a - np_b
    m = statistics.mean(delta)
    s = statistics.stdev(delta)
    return [m, s]

if BASELINE == 'lr':
    plot_algo_lr(orig_metrics_mean, transf_metrics_mean, dir_metrics_mean, reweigh_metrics_mean, egr_metrics_mean, pr_orig_metrics_mean, cpp_metrics_mean, ro_metrics_mean, orig_error_metrics, transf_error_metrics, dir_error_metrics, reweigh_error_metrics, egr_error_metrics, pr_orig_error_metrics, cpp_error_metrics, ro_error_metrics, BASELINE)
    stat =  {k: [paired_t(transf_metrics[k], v)] for (k,v) in orig_metrics.items()}
    print("5)")
    print(stat)
else:
    plot_algo(orig_metrics_mean, transf_metrics_mean, dir_metrics_mean, reweigh_metrics_mean, egr_metrics_mean, cpp_metrics_mean, ro_metrics_mean, orig_error_metrics, transf_error_metrics, dir_error_metrics, reweigh_error_metrics, egr_error_metrics, cpp_error_metrics, ro_error_metrics, BASELINE)
    stat =  {k: [paired_t(transf_metrics[k], v)] for (k,v) in orig_metrics.items()}
    print(stat)

plt.show()
# Out:
# 1)
#
# law_sex
# 10399
# 2)
#
#                total_priv  total_unpriv
# num_instance
# orig          5877.666667   4521.333333
# 3)
#
#          total_favor  total_unfavor  priv_favor  priv_unfavor  unpriv_favor  \
# dataset
# orig        0.948649       0.051351    0.954684      0.045316      0.940799
# transf      0.954683       0.045317    0.954684      0.045316      0.954681
#
#          unpriv_unfavor
# dataset
# orig           0.059201
# transf         0.045319
# 4)
#
#                             bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Classifier Bias Mitigator
# dt_orig                    0.589743      -0.017689  0.007745      -0.007534
# dt_syn                     0.569554      -0.015311  0.006291      -0.006159
# dt_dir                     0.590959      -0.040702  0.015093      -0.014712
# dt_rew                     0.578893      -0.022762  0.007902      -0.007716
# dt_egr                     0.431349       0.028339  0.295003       0.009512
# dt_cpp                     0.549079      -0.108070  0.031881      -0.031806
#
#                            eq_opp_diff  theil_ind  unpriv_fpr  unpriv_fnr  \
# Classifier Bias Mitigator
# dt_orig                      -0.004646   0.035051    0.783023    0.024502
# dt_syn                       -0.003761   0.030840    0.830252    0.018986
# dt_dir                       -0.010048   0.035927    0.758786    0.028462
# dt_rew                       -0.004486   0.032887    0.801928    0.021815
# dt_egr                        0.006068   2.723990    0.183320    0.976420
# dt_cpp                       -0.022494   0.026618    0.791088    0.024426
#
#                            priv_fpr  priv_fnr
# Classifier Bias Mitigator
# dt_orig                    0.813755  0.019856
# dt_syn                     0.857113  0.015225
# dt_dir                     0.830143  0.018414
# dt_rew                     0.842966  0.017329
# dt_egr                     0.132709  0.982487
# dt_cpp                     0.984733  0.001931
# {'bal_acc': [0.011120804436066339], 'avg_odds_diff': [0.8836516301667887], 'disp_imp': [0.42901711621812655], 'stat_par_diff': [0.440895903641241], 'eq_opp_diff': [0.004347767842914533], 'theil_ind': [0.02859311290568065], 'unpriv_fpr': [0.049677975546144], 'unpriv_fnr': [0.01597652886399853], 'priv_fpr': [0.13409586685066932], 'priv_fnr': [0.018974932047176332]}

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Fairness

# %%
model_type = BASELINE
pd.set_option('display.multi_sparse', False)
plt.rcParams.update({'font.size': 8}) # must set in top

results = [orig_metrics_mean,
        transf_metrics_mean,
        dir_metrics_mean,
        reweigh_metrics_mean,
        egr_metrics_mean,
        pr_orig_metrics_mean,
        cpp_metrics_mean,
        ro_metrics_mean]


errors = [orig_error_metrics,
        transf_error_metrics,
        dir_error_metrics,
        reweigh_error_metrics,
        egr_error_metrics,
        pr_orig_error_metrics,
        cpp_error_metrics,
        ro_error_metrics]

index = pd.Series([model_type+'_orig']+ [model_type+'_syn']+ [model_type+'_dir']+ [model_type+'_rew']+ [model_type+'_egr'] + [model_type+'_cpp'], name='Classifier Bias Mitigator')

df = pd.concat([pd.DataFrame(metrics) for metrics in results], axis=0).set_index(index)
df_error = pd.concat([pd.DataFrame(metrics) for metrics in errors], axis=0).set_index(index)
ax = df.plot.bar(yerr=df_error, capsize=4, rot=0, subplots=True, title=['','','','','', '', '', '', '', ''], fontsize = 12, figsize=(10,10))
plot1 = ax[0]
plot1.set_ylim=([0, 0.8])
plot2 = ax[1]
plot2.set_ylim=([-0.5, 0])
plot3 = ax[2]
plot3.set_ylim=([0, 1])
plot4 = ax[3]
plot4.set_ylim=([-0.5, 0])
plot5 = ax[4]
plot5.set_ylim=([-0.5, 0])
plot5 = ax[5]
plot5.set_ylim=([0, 0.2])

plt.legend(bbox_to_anchor=(1.5, 1.0))

# %%
df
# Out:
#                             bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# Classifier Bias Mitigator
# dt_orig                    0.589743      -0.017689  0.007745      -0.007534
# dt_syn                     0.569554      -0.015311  0.006291      -0.006159
# dt_dir                     0.590959      -0.040702  0.015093      -0.014712
# dt_rew                     0.578893      -0.022762  0.007902      -0.007716
# dt_egr                     0.431349       0.028339  0.295003       0.009512
# dt_cpp                     0.549079      -0.108070  0.031881      -0.031806
#
#                            eq_opp_diff  theil_ind  unpriv_fpr  unpriv_fnr  \
# Classifier Bias Mitigator
# dt_orig                      -0.004646   0.035051    0.783023    0.024502
# dt_syn                       -0.003761   0.030840    0.830252    0.018986
# dt_dir                       -0.010048   0.035927    0.758786    0.028462
# dt_rew                       -0.004486   0.032887    0.801928    0.021815
# dt_egr                        0.006068   2.723990    0.183320    0.976420
# dt_cpp                       -0.022494   0.026618    0.791088    0.024426
#
#                            priv_fpr  priv_fnr
# Classifier Bias Mitigator
# dt_orig                    0.813755  0.019856
# dt_syn                     0.857113  0.015225
# dt_dir                     0.830143  0.018414
# dt_rew                     0.842966  0.017329
# dt_egr                     0.132709  0.982487
# dt_cpp                     0.984733  0.001931

# %% [markdown]
# ## Visualization of MIA results

# %% [markdown]
# ### Visualization of MIA Attacks against various Fairness Techniques

# %% [markdown]
# #### Privacy risk subpopulations vs Fairness with cross validation

# %%
# dataframe to display fairness metrics
# error metrics
# %matplotlib inline
orig_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in orig_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
transf_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in transf_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
reweigh_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in reweigh_metrics.items() if k.endswith("_mia_privacy_risk")}
dir_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in dir_metrics.items() if k.endswith("_mia_privacy_risk")}
egr_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in egr_metrics.items() if k.endswith("_mia_privacy_risk")}
# cpp_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in cpp_metrics.items() if k.endswith("_mia_privacy_risk")}

# mean value metrics
orig_mia_metrics_mean = {k: sum(v)/N for (k,v) in orig_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
transf_mia_metrics_mean = {k: sum(v)/N for (k,v) in transf_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
reweigh_mia_metrics_mean = {k:sum(v)/N for (k,v) in reweigh_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
dir_mia_metrics_mean = {k:sum(v)/N for (k,v) in dir_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
egr_mia_metrics_mean = {k:sum(v)/N for (k,v) in egr_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
# cpp_mia_metrics_mean = {k:sum(v)/N for (k,v) in dir_mia_metrics.items() if k.endswith("_mia_privacy_risk")}

# %%
# Visualization of Fairness
pd.set_option('display.multi_sparse', False)
plt.rcParams.update({'font.size': 8}) # must set in top

results = [orig_mia_metrics_mean,
           transf_mia_metrics_mean,
           dir_mia_metrics_mean,
           reweigh_mia_metrics_mean,
           egr_mia_metrics_mean
          ]


errors = [orig_mia_error_metrics,
          transf_mia_error_metrics,
          dir_mia_error_metrics,
          reweigh_mia_error_metrics,
          egr_mia_error_metrics
         ]

index = pd.Series(['orig']+ ['syn']+ ['dir']+ ['rew'] + ['egr'], name='Classifier MIA Attacks')

df = pd.DataFrame(results).set_index(index)
df
# Out:
#                         entire_dataset_mia_privacy_risk  \
# Classifier MIA Attacks
# orig                                           0.516877
# syn                                            0.515130
# dir                                            0.516700
# rew                                            0.515386
# egr                                            0.517982
#
#                         entire_dataset_label_0.0_mia_privacy_risk  \
# Classifier MIA Attacks
# orig                                                     0.687242
# syn                                                      0.673942
# dir                                                      0.675290
# rew                                                      0.665018
# egr                                                      0.683570
#
#                         entire_dataset_label_1.0_mia_privacy_risk  \
# Classifier MIA Attacks
# orig                                                     0.510786
# syn                                                      0.509003
# dir                                                      0.511822
# rew                                                      0.511077
# egr                                                      0.514493
#
#                         subpopulation_0.0_label_0.0_mia_privacy_risk  \
# Classifier MIA Attacks
# orig                                                        0.677461
# syn                                                         0.684352
# dir                                                         0.671839
# rew                                                         0.666380
# egr                                                         0.663856
#
#                         subpopulation_0.0_label_1.0_mia_privacy_risk  \
# Classifier MIA Attacks
# orig                                                        0.512718
# syn                                                         0.513087
# dir                                                         0.517901
# rew                                                         0.513444
# egr                                                         0.512300
#
#                         subpopulation_1.0_label_0.0_mia_privacy_risk  \
# Classifier MIA Attacks
# orig                                                        0.696151
# syn                                                         0.668214
# dir                                                         0.681645
# rew                                                         0.674101
# egr                                                         0.704629
#
#                         subpopulation_1.0_label_1.0_mia_privacy_risk
# Classifier MIA Attacks
# orig                                                        0.510481
# syn                                                         0.508115
# dir                                                         0.509814
# rew                                                         0.509413
# egr                                                         0.516339

# %%
df.columns
# Out:
# Index(['entire_dataset_mia_privacy_risk',
#        'entire_dataset_label_0.0_mia_privacy_risk',
#        'entire_dataset_label_1.0_mia_privacy_risk',
#        'subpopulation_0.0_label_0.0_mia_privacy_risk',
#        'subpopulation_0.0_label_1.0_mia_privacy_risk',
#        'subpopulation_1.0_label_0.0_mia_privacy_risk',
#        'subpopulation_1.0_label_1.0_mia_privacy_risk'],
#       dtype='object')

# %%
df_groups = df[['subpopulation_0.0_label_0.0_mia_privacy_risk',
       'subpopulation_0.0_label_1.0_mia_privacy_risk',
       'subpopulation_1.0_label_0.0_mia_privacy_risk',
       'subpopulation_1.0_label_1.0_mia_privacy_risk']]

# %%
df_groups
# Out:
#                         subpopulation_0.0_label_0.0_mia_privacy_risk  \
# Classifier MIA Attacks
# orig                                                        0.677461
# syn                                                         0.684352
# dir                                                         0.671839
# rew                                                         0.666380
# egr                                                         0.663856
#
#                         subpopulation_0.0_label_1.0_mia_privacy_risk  \
# Classifier MIA Attacks
# orig                                                        0.512718
# syn                                                         0.513087
# dir                                                         0.517901
# rew                                                         0.513444
# egr                                                         0.512300
#
#                         subpopulation_1.0_label_0.0_mia_privacy_risk  \
# Classifier MIA Attacks
# orig                                                        0.696151
# syn                                                         0.668214
# dir                                                         0.681645
# rew                                                         0.674101
# egr                                                         0.704629
#
#                         subpopulation_1.0_label_1.0_mia_privacy_risk
# Classifier MIA Attacks
# orig                                                        0.510481
# syn                                                         0.508115
# dir                                                         0.509814
# rew                                                         0.509413
# egr                                                         0.516339

# %%
df_groups.plot.bar(figsize=(7,7), ylim=[0,1])
# Out:
# <Axes: xlabel='Classifier MIA Attacks'>

# %%
# Tabular Format
# importing the modules
from tabulate import tabulate

# displaying the DataFrame
print(tabulate(df_groups.T, headers = 'keys', tablefmt = 'simple'))
# Out:
#                                                   orig       syn       dir       rew       egr
# --------------------------------------------  --------  --------  --------  --------  --------
# subpopulation_0.0_label_0.0_mia_privacy_risk  0.677461  0.684352  0.671839  0.66638   0.663856
# subpopulation_0.0_label_1.0_mia_privacy_risk  0.512718  0.513087  0.517901  0.513444  0.5123
# subpopulation_1.0_label_0.0_mia_privacy_risk  0.696151  0.668214  0.681645  0.674101  0.704629
# subpopulation_1.0_label_1.0_mia_privacy_risk  0.510481  0.508115  0.509814  0.509413  0.516339

# %% [markdown]
# ### Visualizing using novel technique

# %%
orig_mia_error_metrics = {k: v for (k,v) in orig_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
transf_mia_error_metrics = {k: v for (k,v) in transf_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
reweigh_mia_error_metrics = {k: v for (k,v) in reweigh_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
dir_mia_error_metrics = {k: v for (k,v) in dir_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
egr_mia_error_metrics = {k: v for (k,v) in egr_mia_metrics.items() if k.endswith("_mia_privacy_risk")}
#orig_mia_metrics

# %%
advantage_metrics_arrays = []
for key in orig_mia_error_metrics.keys():
    for val in orig_mia_metrics[key]:
        advantage_metrics_arrays.append(["orig", key.replace("_mia_attacker_advantage", ""), val])
for key in transf_mia_error_metrics.keys():
    for val in transf_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["syn", key.replace("_mia_attacker_advantage", ""), val])
for key in reweigh_mia_error_metrics.keys():
    for val in reweigh_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["reweigh", key.replace("_mia_attacker_advantage", ""), val])
for key in dir_mia_error_metrics.keys():
    for val in dir_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["dir", key.replace("_mia_attacker_advantage", ""), val])
for key in egr_mia_error_metrics.keys():
    for val in egr_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["egr", key.replace("_mia_attacker_advantage", ""), val])

# %%
df = pd.DataFrame(advantage_metrics_arrays,columns=["Fairness", "MIA", "Privacy Risk"])
df
# Out:
#     Fairness                                           MIA  Privacy Risk
# 0       orig               entire_dataset_mia_privacy_risk      0.514665
# 1       orig               entire_dataset_mia_privacy_risk      0.517982
# 2       orig               entire_dataset_mia_privacy_risk      0.517982
# 3       orig     entire_dataset_label_0.0_mia_privacy_risk      0.672380
# 4       orig     entire_dataset_label_0.0_mia_privacy_risk      0.694673
# ..       ...                                           ...           ...
# 100      egr  subpopulation_1.0_label_0.0_mia_privacy_risk      0.718116
# 101      egr  subpopulation_1.0_label_0.0_mia_privacy_risk      0.718116
# 102      egr  subpopulation_1.0_label_1.0_mia_privacy_risk      0.513381
# 103      egr  subpopulation_1.0_label_1.0_mia_privacy_risk      0.517817
# 104      egr  subpopulation_1.0_label_1.0_mia_privacy_risk      0.517817
#
# [105 rows x 3 columns]

# %%
# keep only subgroups
df_subgroups = df[~((df["MIA"] == "entire_dataset_label_0.0_mia_privacy_risk") | (df["MIA"] == "entire_dataset_label_1.0_mia_privacy_risk")) ]
df_subgroups
# Out:
#     Fairness                                           MIA  Privacy Risk
# 0       orig               entire_dataset_mia_privacy_risk      0.514665
# 1       orig               entire_dataset_mia_privacy_risk      0.517982
# 2       orig               entire_dataset_mia_privacy_risk      0.517982
# 9       orig  subpopulation_0.0_label_0.0_mia_privacy_risk      0.672681
# 10      orig  subpopulation_0.0_label_0.0_mia_privacy_risk      0.679851
# ..       ...                                           ...           ...
# 100      egr  subpopulation_1.0_label_0.0_mia_privacy_risk      0.718116
# 101      egr  subpopulation_1.0_label_0.0_mia_privacy_risk      0.718116
# 102      egr  subpopulation_1.0_label_1.0_mia_privacy_risk      0.513381
# 103      egr  subpopulation_1.0_label_1.0_mia_privacy_risk      0.517817
# 104      egr  subpopulation_1.0_label_1.0_mia_privacy_risk      0.517817
#
# [75 rows x 3 columns]

# %%
#plt.figure(figsize=(15,8))
import seaborn as sns

sns.set_theme()
#sns.set_style('ticks')

g = sns.catplot(
    data=df_subgroups, x="MIA", y="Privacy Risk", hue="Fairness",
    #palette={"male": "g", "female": "m"},
    markers=["^", "o", "x", "v", ">"], linestyles=["-", "--", "-.", ":", "-"],
    kind="point", height=8, aspect=1
)
plt.xticks(rotation=30)

g.set_axis_labels("Classifier Membership Inference Attacks", "Privacy Risk" )
g.set(ylim=(0, 1))

# %% [markdown]
# ### ROC curves and AUC scores with cross validation

# %%
from sklearn.metrics import RocCurveDisplay, auc

# %%
orig_mia_metrics.keys()
# Out:
# dict_keys(['entire_dataset_mia_auc', 'entire_dataset_mia_privacy_risk', 'entire_dataset_mia_ppv', 'entire_dataset_mia_attacker_advantage', 'entire_dataset_mia_result', 'entire_dataset_label_0.0_mia_auc', 'entire_dataset_label_0.0_mia_privacy_risk', 'entire_dataset_label_0.0_mia_ppv', 'entire_dataset_label_0.0_mia_attacker_advantage', 'entire_dataset_label_0.0_mia_result', 'entire_dataset_label_1.0_mia_auc', 'entire_dataset_label_1.0_mia_privacy_risk', 'entire_dataset_label_1.0_mia_ppv', 'entire_dataset_label_1.0_mia_attacker_advantage', 'entire_dataset_label_1.0_mia_result', 'subpopulation_0.0_label_0.0_mia_auc', 'subpopulation_0.0_label_0.0_mia_privacy_risk', 'subpopulation_0.0_label_0.0_mia_ppv', 'subpopulation_0.0_label_0.0_mia_attacker_advantage', 'subpopulation_0.0_label_0.0_mia_result', 'subpopulation_0.0_label_1.0_mia_auc', 'subpopulation_0.0_label_1.0_mia_privacy_risk', 'subpopulation_0.0_label_1.0_mia_ppv', 'subpopulation_0.0_label_1.0_mia_attacker_advantage', 'subpopulation_0.0_label_1.0_mia_result', 'subpopulation_1.0_label_0.0_mia_auc', 'subpopulation_1.0_label_0.0_mia_privacy_risk', 'subpopulation_1.0_label_0.0_mia_ppv', 'subpopulation_1.0_label_0.0_mia_attacker_advantage', 'subpopulation_1.0_label_0.0_mia_result', 'subpopulation_1.0_label_1.0_mia_auc', 'subpopulation_1.0_label_1.0_mia_privacy_risk', 'subpopulation_1.0_label_1.0_mia_ppv', 'subpopulation_1.0_label_1.0_mia_attacker_advantage', 'subpopulation_1.0_label_1.0_mia_result'])

# %%
# for orig dataset with different subpopulations
fig, ax = plt.subplots(figsize=(10, 8))

for key in ["entire_dataset_mia_result", "subpopulation_0.0_label_0.0_mia_result",
            "subpopulation_0.0_label_1.0_mia_result", "subpopulation_1.0_label_0.0_mia_result", "subpopulation_1.0_label_1.0_mia_result"]:
     # fprs = [mia_res.fpr for mia_res in orig_mia_metrics[key]]
    # tprs = [mia_res.tpr for mia_res in orig_mia_metrics[key]]
    tprs = []
    
    # aucs = [mia_res.get_auc() for mia_res in orig_mia_metrics[key]]
    aucs = []

    # mean_fpr = np.mean(fprs, axis=0)
    mean_fpr = np.linspace(0, 1, 100)
    
    for mia_res in orig_mia_metrics[key]:
        interp_tpr = np.interp(mean_fpr, mia_res.fpr, mia_res.tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(mia_res.get_auc())
    
    #print(mean_fpr)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    
    ax.plot(
        mean_fpr,
        mean_tpr,
        #color="b",
        label=r"Mean ROC for %s $\pm$ 1 std. dev. (AUC = %0.2f $\pm$ %0.2f)" % ( key ,mean_auc, std_auc),
        lw=2,
        alpha=0.8,
    )

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    ax.fill_between(
        mean_fpr,
        tprs_lower,
        tprs_upper,
        color="grey",
        alpha=0.2,
        #label=r"$\pm$ 1 std. dev.",
    )


plt.plot([0, 1], [0, 1],'k--', alpha=0.5)

ax.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"Mean ROC curve with variability",
)
ax.legend(loc="lower right")
plt.show()

# %%
# for entire dataset with different subpopulations
# fig, ax = plt.subplots(figsize=(12, 10))
fig, ax = plt.subplots(figsize=(24, 18))

for mia_metrics, name in zip([orig_mia_metrics, transf_mia_metrics, dir_mia_metrics, reweigh_mia_metrics], ["orig", "syn", "dir", "reweigh"] ):
    for key in ["entire_dataset_mia_result", "subpopulation_0.0_label_0.0_mia_result",
            "subpopulation_0.0_label_1.0_mia_result", "subpopulation_1.0_label_0.0_mia_result",
                "subpopulation_1.0_label_1.0_mia_result"]:
   
        # fprs = [mia_res.fpr for mia_res in orig_mia_metrics[key]]
        # tprs = [mia_res.tpr for mia_res in orig_mia_metrics[key]]
        tprs = []
        # aucs = [mia_res.get_auc() for mia_res in orig_mia_metrics[key]]
        aucs = []

        # mean_fpr = np.mean(fprs, axis=0)
        mean_fpr = np.linspace(0, 1, 100)

        for mia_res in mia_metrics[key]:
            interp_tpr = np.interp(mean_fpr, mia_res.fpr, mia_res.tpr)
            interp_tpr[0] = 0.0
            tprs.append(interp_tpr)
            aucs.append(mia_res.get_auc())

        #print(mean_fpr)
        mean_tpr = np.mean(tprs, axis=0)
        mean_tpr[-1] = 1.0

        mean_auc = auc(mean_fpr, mean_tpr)
        std_auc = np.std(aucs)

        ax.plot(
            mean_fpr,
            mean_tpr,
            #color="b",
            label=r"%s Mean ROC for %s $\pm$ 1 std. dev. (AUC = %0.2f $\pm$ %0.2f)" % (name, key ,mean_auc, std_auc),
            lw=2,
            alpha=0.8,
        )

        std_tpr = np.std(tprs, axis=0)
        tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
        tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
        ax.fill_between(
            mean_fpr,
            tprs_lower,
            tprs_upper,
            color="grey",
            alpha=0.2,
            #label=r"$\pm$ 1 std. dev.",
        )


plt.plot([0, 1], [0, 1],'k--', alpha=0.5)

ax.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"Mean ROC curve for MIA attacks against Fairness Approaches",
)
ax.legend(loc="lower right")
# ax.legend(loc="upper left")

plt.show()

# %%
# for entire dataset
plt.figure(figsize=(10,8))

for mia_res in orig_mia_metrics["entire_dataset_mia_result"]:
    plt.plot(mia_res.fpr,mia_res.tpr,label=f"{mia_res.get_name()} auc={mia_res.get_auc()}")

plt.plot([0, 1], [0, 1],'k--', alpha=0.5)
plt.legend(loc=0)

# %% [markdown]
# ## MIA Attacks AUC vs Fairness Bar Chart

# %%
# dataframe to display fairness metrics
# error metrics
orig_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in orig_mia_metrics.items() if k.endswith("mia_auc")}
transf_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in transf_mia_metrics.items() if k.endswith("mia_auc")}
reweigh_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in reweigh_metrics.items() if k.endswith("mia_auc")}
dir_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in dir_metrics.items() if k.endswith("mia_auc")}


# mean value metrics
orig_mia_metrics_mean = {k: sum(v)/N for (k,v) in orig_mia_metrics.items() if k.endswith("mia_auc")}
transf_mia_metrics_mean = {k: sum(v)/N for (k,v) in transf_mia_metrics.items() if k.endswith("mia_auc")}
reweigh_mia_metrics_mean = {k:sum(v)/N for (k,v) in reweigh_mia_metrics.items() if k.endswith("mia_auc")}
dir_mia_metrics_mean = {k:sum(v)/N for (k,v) in dir_mia_metrics.items() if k.endswith("mia_auc")}

# %%
orig_mia_metrics_mean
# Out:
# {'entire_dataset_mia_auc': 0.5190599105684163,
#  'entire_dataset_label_0.0_mia_auc': 0.7365488295924371,
#  'entire_dataset_label_1.0_mia_auc': 0.5108945209535766,
#  'subpopulation_0.0_label_0.0_mia_auc': 0.7236497670667713,
#  'subpopulation_0.0_label_1.0_mia_auc': 0.51319488256747,
#  'subpopulation_1.0_label_0.0_mia_auc': 0.7505224183184703,
#  'subpopulation_1.0_label_1.0_mia_auc': 0.5088349002151266}

# %%
# Visuazlization of Fairness
pd.set_option('display.multi_sparse', False)
plt.rcParams.update({'font.size': 8}) # must set in top

results = [orig_mia_metrics_mean,
        transf_mia_metrics_mean,
        dir_mia_metrics_mean,
        reweigh_mia_metrics_mean,
        ]


errors = [orig_mia_error_metrics,
        transf_mia_error_metrics,
        dir_mia_error_metrics,
        reweigh_mia_error_metrics
         ]

index = pd.Series(['orig']+ ['syn']+ ['dir']+ ['rew'], name='Classifier MIA Attacks')

df = pd.DataFrame(results).set_index(index)
df
# Out:
#                         entire_dataset_mia_auc  \
# Classifier MIA Attacks
# orig                                  0.519060
# syn                                   0.514598
# dir                                   0.517595
# rew                                   0.520265
#
#                         entire_dataset_label_0.0_mia_auc  \
# Classifier MIA Attacks
# orig                                            0.736549
# syn                                             0.731981
# dir                                             0.725124
# rew                                             0.728534
#
#                         entire_dataset_label_1.0_mia_auc  \
# Classifier MIA Attacks
# orig                                            0.510895
# syn                                             0.505523
# dir                                             0.510486
# rew                                             0.511119
#
#                         subpopulation_0.0_label_0.0_mia_auc  \
# Classifier MIA Attacks
# orig                                               0.723650
# syn                                                0.736563
# dir                                                0.710401
# rew                                                0.716337
#
#                         subpopulation_0.0_label_1.0_mia_auc  \
# Classifier MIA Attacks
# orig                                               0.513195
# syn                                                0.507675
# dir                                                0.512987
# rew                                                0.511524
#
#                         subpopulation_1.0_label_0.0_mia_auc  \
# Classifier MIA Attacks
# orig                                               0.750522
# syn                                                0.727692
# dir                                                0.739546
# rew                                                0.739855
#
#                         subpopulation_1.0_label_1.0_mia_auc
# Classifier MIA Attacks
# orig                                               0.508835
# syn                                                0.503879
# dir                                                0.508793
# rew                                                0.510513

# %%
df.plot.bar(figsize=(7,7), ylim=[0,1])
# Out:
# <Axes: xlabel='Classifier MIA Attacks'>

# %% [markdown]
# ###  MIA Attackers Advantage Metrics

# %%
# Creating data structures to plot point categorical plot from seaborn

# %%
orig_mia_metrics_att_ad = {k: v for (k,v) in orig_mia_metrics.items() if k.endswith("attacker_advantage")}
transf_mia_error_metrics = {k: v for (k,v) in transf_mia_metrics.items() if k.endswith("attacker_advantage")}
reweigh_mia_error_metrics = {k: v for (k,v) in reweigh_mia_metrics.items() if k.endswith("attacker_advantage")}
dir_mia_error_metrics = {k: v for (k,v) in dir_mia_metrics.items() if k.endswith("attacker_advantage")}
egr_mia_error_metrics = {k: v for (k,v) in egr_mia_metrics.items() if k.endswith("attacker_advantage")}

# %%
orig_mia_metrics_att_ad
# Out:
# {'entire_dataset_mia_attacker_advantage': [0.02932974324454274,
#   0.03596499663429176,
#   0.03596499663429176],
#  'entire_dataset_label_0.0_mia_attacker_advantage': [0.34475911024170486,
#   0.3893451720310766,
#   0.3893451720310766],
#  'entire_dataset_label_1.0_mia_attacker_advantage': [0.022752048567825534,
#   0.020981009583312615,
#   0.020981009583312615],
#  'subpopulation_0.0_label_0.0_mia_attacker_advantage': [0.3453622268564693,
#   0.3597015826990456,
#   0.3597015826990456],
#  'subpopulation_0.0_label_1.0_mia_attacker_advantage': [0.02646881260733891,
#   0.024920396627058805,
#   0.024920396627058805],
#  'subpopulation_1.0_label_0.0_mia_attacker_advantage': [0.3437118437118437,
#   0.41659652279917564,
#   0.41659652279917564],
#  'subpopulation_1.0_label_1.0_mia_attacker_advantage': [0.020172068750281547,
#   0.021357220130651555,
#   0.021357220130651555]}

# %%
advantage_metrics_arrays = []
for key in orig_mia_metrics_att_ad.keys():
    for val in orig_mia_metrics_att_ad[key]:
        advantage_metrics_arrays.append(["orig", key.replace("_mia_attacker_advantage", ""), val])
for key in transf_mia_error_metrics.keys():
    for val in transf_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["syn", key.replace("_mia_attacker_advantage", ""), val])
for key in reweigh_mia_error_metrics.keys():
    for val in reweigh_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["reweigh", key.replace("_mia_attacker_advantage", ""), val])
for key in dir_mia_error_metrics.keys():
    for val in dir_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["dir", key.replace("_mia_attacker_advantage", ""), val])
for key in egr_mia_error_metrics.keys():
    for val in egr_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["egr", key.replace("_mia_attacker_advantage", ""), val])
advantage_metrics_arrays
# Out:
# [['orig', 'entire_dataset', 0.02932974324454274],
#  ['orig', 'entire_dataset', 0.03596499663429176],
#  ['orig', 'entire_dataset', 0.03596499663429176],
#  ['orig', 'entire_dataset_label_0.0', 0.34475911024170486],
#  ['orig', 'entire_dataset_label_0.0', 0.3893451720310766],
#  ['orig', 'entire_dataset_label_0.0', 0.3893451720310766],
#  ['orig', 'entire_dataset_label_1.0', 0.022752048567825534],
#  ['orig', 'entire_dataset_label_1.0', 0.020981009583312615],
#  ['orig', 'entire_dataset_label_1.0', 0.020981009583312615],
#  ['orig', 'subpopulation_0.0_label_0.0', 0.3453622268564693],
#  ['orig', 'subpopulation_0.0_label_0.0', 0.3597015826990456],
#  ['orig', 'subpopulation_0.0_label_0.0', 0.3597015826990456],
#  ['orig', 'subpopulation_0.0_label_1.0', 0.02646881260733891],
#  ['orig', 'subpopulation_0.0_label_1.0', 0.024920396627058805],
#  ['orig', 'subpopulation_0.0_label_1.0', 0.024920396627058805],
#  ['orig', 'subpopulation_1.0_label_0.0', 0.3437118437118437],
#  ['orig', 'subpopulation_1.0_label_0.0', 0.41659652279917564],
#  ['orig', 'subpopulation_1.0_label_0.0', 0.41659652279917564],
#  ['orig', 'subpopulation_1.0_label_1.0', 0.020172068750281547],
#  ['orig', 'subpopulation_1.0_label_1.0', 0.021357220130651555],
#  ['orig', 'subpopulation_1.0_label_1.0', 0.021357220130651555],
#  ['syn', 'entire_dataset', 0.03384940859698049],
#  ['syn', 'entire_dataset', 0.028464275411097306],
#  ['syn', 'entire_dataset', 0.028464275411097306],
#  ['syn', 'entire_dataset_label_0.0', 0.4258954637739148],
#  ['syn', 'entire_dataset_label_0.0', 0.30887902330743616],
#  ['syn', 'entire_dataset_label_0.0', 0.30887902330743616],
#  ['syn', 'entire_dataset_label_1.0', 0.020140918887182946],
#  ['syn', 'entire_dataset_label_1.0', 0.016937525224899663],
#  ['syn', 'entire_dataset_label_1.0', 0.016937525224899663],
#  ['syn', 'subpopulation_0.0_label_0.0', 0.4599842838577085],
#  ['syn', 'subpopulation_0.0_label_0.0', 0.32306391204542706],
#  ['syn', 'subpopulation_0.0_label_0.0', 0.32306391204542706],
#  ['syn', 'subpopulation_0.0_label_1.0', 0.02929319632749139],
#  ['syn', 'subpopulation_0.0_label_1.0', 0.024614250574982233],
#  ['syn', 'subpopulation_0.0_label_1.0', 0.024614250574982233],
#  ['syn', 'subpopulation_1.0_label_0.0', 0.3962148962148962],
#  ['syn', 'subpopulation_1.0_label_0.0', 0.30653353844367687],
#  ['syn', 'subpopulation_1.0_label_0.0', 0.30653353844367687],
#  ['syn', 'subpopulation_1.0_label_1.0', 0.019953282755159063],
#  ['syn', 'subpopulation_1.0_label_1.0', 0.014367402504176563],
#  ['syn', 'subpopulation_1.0_label_1.0', 0.014367402504176563],
#  ['reweigh', 'entire_dataset', 0.03423406096740078],
#  ['reweigh', 'entire_dataset', 0.02904125396672752],
#  ['reweigh', 'entire_dataset', 0.02904125396672752],
#  ['reweigh', 'entire_dataset_label_0.0', 0.3387572429941167],
#  ['reweigh', 'entire_dataset_label_0.0', 0.32567517573066956],
#  ['reweigh', 'entire_dataset_label_0.0', 0.32567517573066956],
#  ['reweigh', 'entire_dataset_label_1.0', 0.02660221758972714],
#  ['reweigh', 'entire_dataset_label_1.0', 0.019931237752324638],
#  ['reweigh', 'entire_dataset_label_1.0', 0.019931237752324638],
#  ['reweigh', 'subpopulation_0.0_label_0.0', 0.35613685133133866],
#  ['reweigh', 'subpopulation_0.0_label_0.0', 0.3210704361483629],
#  ['reweigh', 'subpopulation_0.0_label_0.0', 0.3210704361483629],
#  ['reweigh', 'subpopulation_0.0_label_1.0', 0.03027739563943188],
#  ['reweigh', 'subpopulation_0.0_label_1.0', 0.02519317437927948],
#  ['reweigh', 'subpopulation_0.0_label_1.0', 0.02519317437927948],
#  ['reweigh', 'subpopulation_1.0_label_0.0', 0.3412698412698413],
#  ['reweigh', 'subpopulation_1.0_label_0.0', 0.35166748904304423],
#  ['reweigh', 'subpopulation_1.0_label_0.0', 0.35166748904304423],
#  ['reweigh', 'subpopulation_1.0_label_1.0', 0.024143034561752375],
#  ['reweigh', 'subpopulation_1.0_label_1.0', 0.01616726550016001],
#  ['reweigh', 'subpopulation_1.0_label_1.0', 0.01616726550016001],
#  ['dir', 'entire_dataset', 0.030387537263198316],
#  ['dir', 'entire_dataset', 0.03490720261563607],
#  ['dir', 'entire_dataset', 0.03490720261563607],
#  ['dir', 'entire_dataset_label_0.0', 0.31655774389069197],
#  ['dir', 'entire_dataset_label_0.0', 0.367591564927858],
#  ['dir', 'entire_dataset_label_0.0', 0.367591564927858],
#  ['dir', 'entire_dataset_label_1.0', 0.022944119492727455],
#  ['dir', 'entire_dataset_label_1.0', 0.02399284812456881],
#  ['dir', 'entire_dataset_label_1.0', 0.02399284812456881],
#  ['dir', 'subpopulation_0.0_label_0.0', 0.3289358358267598],
#  ['dir', 'subpopulation_0.0_label_0.0', 0.35104808505497165],
#  ['dir', 'subpopulation_0.0_label_0.0', 0.35104808505497165],
#  ['dir', 'subpopulation_0.0_label_1.0', 0.03016445915977739],
#  ['dir', 'subpopulation_0.0_label_1.0', 0.038621053388631865],
#  ['dir', 'subpopulation_0.0_label_1.0', 0.038621053388631865],
#  ['dir', 'subpopulation_1.0_label_0.0', 0.32509157509157505],
#  ['dir', 'subpopulation_1.0_label_0.0', 0.3823905030040925],
#  ['dir', 'subpopulation_1.0_label_0.0', 0.3823905030040925],
#  ['dir', 'subpopulation_1.0_label_1.0', 0.019811715346550574],
#  ['dir', 'subpopulation_1.0_label_1.0', 0.019536795913729255],
#  ['dir', 'subpopulation_1.0_label_1.0', 0.019536795913729255],
#  ['egr', 'entire_dataset', 0.03731127993076255],
#  ['egr', 'entire_dataset', 0.03529185498605625],
#  ['egr', 'entire_dataset', 0.03529185498605625],
#  ['egr', 'entire_dataset_label_0.0', 0.34862698024570604],
#  ['egr', 'entire_dataset_label_0.0', 0.3763965963743988],
#  ['egr', 'entire_dataset_label_0.0', 0.3763965963743988],
#  ['egr', 'entire_dataset_label_1.0', 0.028754313641953022],
#  ['egr', 'entire_dataset_label_1.0', 0.029101545751416547],
#  ['egr', 'entire_dataset_label_1.0', 0.029101545751416547],
#  ['egr', 'subpopulation_0.0_label_0.0', 0.34172031311391177],
#  ['egr', 'subpopulation_0.0_label_0.0', 0.32070798598526035],
#  ['egr', 'subpopulation_0.0_label_0.0', 0.32070798598526035],
#  ['egr', 'subpopulation_0.0_label_1.0', 0.03130240756065461],
#  ['egr', 'subpopulation_0.0_label_1.0', 0.021247399918317922],
#  ['egr', 'subpopulation_0.0_label_1.0', 0.021247399918317922],
#  ['egr', 'subpopulation_1.0_label_0.0', 0.3553113553113553],
#  ['egr', 'subpopulation_1.0_label_0.0', 0.43623196818854676],
#  ['egr', 'subpopulation_1.0_label_0.0', 0.43623196818854676],
#  ['egr', 'subpopulation_1.0_label_1.0', 0.026761388132790165],
#  ['egr', 'subpopulation_1.0_label_1.0', 0.03563484828988406],
#  ['egr', 'subpopulation_1.0_label_1.0', 0.03563484828988406]]

# %%
df = pd.DataFrame(advantage_metrics_arrays,columns=["Fairness", "MIA", "attacker_advantage"])
df
# Out:
#     Fairness                          MIA  attacker_advantage
# 0       orig               entire_dataset            0.029330
# 1       orig               entire_dataset            0.035965
# 2       orig               entire_dataset            0.035965
# 3       orig     entire_dataset_label_0.0            0.344759
# 4       orig     entire_dataset_label_0.0            0.389345
# ..       ...                          ...                 ...
# 100      egr  subpopulation_1.0_label_0.0            0.436232
# 101      egr  subpopulation_1.0_label_0.0            0.436232
# 102      egr  subpopulation_1.0_label_1.0            0.026761
# 103      egr  subpopulation_1.0_label_1.0            0.035635
# 104      egr  subpopulation_1.0_label_1.0            0.035635
#
# [105 rows x 3 columns]

# %%
# Plotting without scaling y limis to 1
import seaborn as sns
sns.set_theme()
#sns.set_style('ticks')

g = sns.catplot(
    data=df, x="MIA", y="attacker_advantage", hue="Fairness",
    #palette={"male": "g", "female": "m"},
    markers=["^", "o", "x", "v", ">"], linestyles=["-", "--", "-.", ":", "-"],
    kind="point", height=8, aspect=1
)

plt.xticks(rotation=30)
g.set_axis_labels("Classifier Membership Inference Attacks", "Attacker's Advantage" )

# %%
#plt.figure(figsize=(15,8))

sns.set_theme()
#sns.set_style('ticks')

g = sns.catplot(
    data=df, x="MIA", y="attacker_advantage", hue="Fairness",
    #palette={"male": "g", "female": "m"},
    markers=["^", "o", "x", "v", ">"], linestyles=["-", "--", "-.", ":", "-"],
    kind="point", height=8, aspect=1
)
plt.xticks(rotation=30)

g.set_axis_labels("Classifier Membership Inference Attacks", "Attacker's Advantage" )
g.set(ylim=(0, 1))

# %%
pd.DataFrame(orig_mia_metrics_att_ad)
# Out:
#    entire_dataset_mia_attacker_advantage  \
# 0                               0.029330
# 1                               0.035965
# 2                               0.035965
#
#    entire_dataset_label_0.0_mia_attacker_advantage  \
# 0                                         0.344759
# 1                                         0.389345
# 2                                         0.389345
#
#    entire_dataset_label_1.0_mia_attacker_advantage  \
# 0                                         0.022752
# 1                                         0.020981
# 2                                         0.020981
#
#    subpopulation_0.0_label_0.0_mia_attacker_advantage  \
# 0                                           0.345362
# 1                                           0.359702
# 2                                           0.359702
#
#    subpopulation_0.0_label_1.0_mia_attacker_advantage  \
# 0                                           0.026469
# 1                                           0.024920
# 2                                           0.024920
#
#    subpopulation_1.0_label_0.0_mia_attacker_advantage  \
# 0                                           0.343712
# 1                                           0.416597
# 2                                           0.416597
#
#    subpopulation_1.0_label_1.0_mia_attacker_advantage
# 0                                           0.020172
# 1                                           0.021357
# 2                                           0.021357

# %%
# dataframe to display fairness metrics
# error metrics
orig_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in orig_mia_metrics.items() if k.endswith("attacker_advantage")}
transf_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in transf_mia_metrics.items() if k.endswith("attacker_advantage")}
reweigh_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in reweigh_metrics.items() if k.endswith("attacker_advantage")}
dir_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in dir_metrics.items() if k.endswith("attacker_advantage")}
egr_mia_error_metrics = {k: statistics.stdev(v) for (k,v) in egr_metrics.items() if k.endswith("attacker_advantage")}

# mean value metrics
orig_mia_metrics_mean = {k: sum(v)/N for (k,v) in orig_mia_metrics.items() if k.endswith("attacker_advantage")}
transf_mia_metrics_mean = {k: sum(v)/N for (k,v) in transf_mia_metrics.items() if k.endswith("attacker_advantage")}
reweigh_mia_metrics_mean = {k:sum(v)/N for (k,v) in reweigh_mia_metrics.items() if k.endswith("attacker_advantage")}
dir_mia_metrics_mean = {k:sum(v)/N for (k,v) in dir_mia_metrics.items() if k.endswith("attacker_advantage")}
egr_mia_metrics_mean = {k:sum(v)/N for (k,v) in egr_mia_metrics.items() if k.endswith("attacker_advantage")}

# %%
orig_mia_metrics_mean
# Out:
# {'entire_dataset_mia_attacker_advantage': 0.03375324550437542,
#  'entire_dataset_label_0.0_mia_attacker_advantage': 0.37448315143461935,
#  'entire_dataset_label_1.0_mia_attacker_advantage': 0.021571355911483587,
#  'subpopulation_0.0_label_0.0_mia_attacker_advantage': 0.3549217974181868,
#  'subpopulation_0.0_label_1.0_mia_attacker_advantage': 0.025436535287152173,
#  'subpopulation_1.0_label_0.0_mia_attacker_advantage': 0.392301629770065,
#  'subpopulation_1.0_label_1.0_mia_attacker_advantage': 0.02096216967052822}

# %%
# Visuazlization of Fairness
pd.set_option('display.multi_sparse', False)
plt.rcParams.update({'font.size': 8}) # must set in top

results = [orig_mia_metrics_mean,
        transf_mia_metrics_mean,
        dir_mia_metrics_mean,
        reweigh_mia_metrics_mean,
           egr_mia_metrics_mean
        ]


errors = [orig_mia_error_metrics,
        transf_mia_error_metrics,
        dir_mia_error_metrics,
        reweigh_mia_error_metrics,
          egr_mia_error_metrics
         ]

index = pd.Series(['orig']+ ['syn']+ ['dir']+ ['rew'] + ['egr'], name='Classifier MIA Attacks')

df = pd.DataFrame(results).set_index(index)
df
# Out:
#                         entire_dataset_mia_attacker_advantage  \
# Classifier MIA Attacks
# orig                                                 0.033753
# syn                                                  0.030259
# dir                                                  0.033401
# rew                                                  0.030772
# egr                                                  0.035965
#
#                         entire_dataset_label_0.0_mia_attacker_advantage  \
# Classifier MIA Attacks
# orig                                                           0.374483
# syn                                                            0.347885
# dir                                                            0.350580
# rew                                                            0.330036
# egr                                                            0.367140
#
#                         entire_dataset_label_1.0_mia_attacker_advantage  \
# Classifier MIA Attacks
# orig                                                           0.021571
# syn                                                            0.018005
# dir                                                            0.023643
# rew                                                            0.022155
# egr                                                            0.028986
#
#                         subpopulation_0.0_label_0.0_mia_attacker_advantage  \
# Classifier MIA Attacks
# orig                                                             0.354922
# syn                                                              0.368704
# dir                                                              0.343677
# rew                                                              0.332759
# egr                                                              0.327712
#
#                         subpopulation_0.0_label_1.0_mia_attacker_advantage  \
# Classifier MIA Attacks
# orig                                                             0.025437
# syn                                                              0.026174
# dir                                                              0.035802
# rew                                                              0.026888
# egr                                                              0.024599
#
#                         subpopulation_1.0_label_0.0_mia_attacker_advantage  \
# Classifier MIA Attacks
# orig                                                             0.392302
# syn                                                              0.336427
# dir                                                              0.363291
# rew                                                              0.348202
# egr                                                              0.409258
#
#                         subpopulation_1.0_label_1.0_mia_attacker_advantage
# Classifier MIA Attacks
# orig                                                             0.020962
# syn                                                              0.016229
# dir                                                              0.019628
# rew                                                              0.018826
# egr                                                              0.032677

# %%
df.plot.bar(figsize=(7,7), ylim=[0,1])
# Out:
# <Axes: xlabel='Classifier MIA Attacks'>

# %% [markdown]
# ## PPV Metric

# %%
orig_mia_metrics_att_ad = {k: v for (k,v) in orig_mia_metrics.items() if k.endswith("mia_ppv")}
transf_mia_error_metrics = {k: v for (k,v) in transf_mia_metrics.items() if k.endswith("mia_ppv")}
reweigh_mia_error_metrics = {k: v for (k,v) in reweigh_mia_metrics.items() if k.endswith("mia_ppv")}
dir_mia_error_metrics = {k: v for (k,v) in dir_mia_metrics.items() if k.endswith("mia_ppv")}
egr_mia_error_metrics = {k: v for (k,v) in egr_mia_metrics.items() if k.endswith("mia_ppv")}

# %%
advantage_metrics_arrays = []
for key in orig_mia_metrics_att_ad.keys():
    for val in orig_mia_metrics_att_ad[key]:
        advantage_metrics_arrays.append(["orig", key.replace("_mia_ppv", ""), val])
for key in transf_mia_error_metrics.keys():
    for val in transf_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["syn", key.replace("_mia_ppv", ""), val])
for key in reweigh_mia_error_metrics.keys():
    for val in reweigh_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["reweigh", key.replace("_mia_ppv", ""), val])
for key in dir_mia_error_metrics.keys():
    for val in dir_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["dir", key.replace("_mia_ppv", ""), val])
for key in egr_mia_error_metrics.keys():
    for val in egr_mia_error_metrics[key]:
        advantage_metrics_arrays.append(["egr", key.replace("_mia_ppv", ""), val])
advantage_metrics_arrays
# Out:
# [['orig', 'entire_dataset', 0.5367264314632736],
#  ['orig', 'entire_dataset', 0.511522478277295],
#  ['orig', 'entire_dataset', 0.511522478277295],
#  ['orig', 'entire_dataset_label_0.0', 0.7857142857142857],
#  ['orig', 'entire_dataset_label_0.0', 0.7117117117117118],
#  ['orig', 'entire_dataset_label_0.0', 0.7117117117117118],
#  ['orig', 'entire_dataset_label_1.0', 0.5212307692307693],
#  ['orig', 'entire_dataset_label_1.0', 0.5069997679634929],
#  ['orig', 'entire_dataset_label_1.0', 0.5069997679634929],
#  ['orig', 'subpopulation_0.0_label_0.0', 0.7294685990338164],
#  ['orig', 'subpopulation_0.0_label_0.0', 0.7219251336898396],
#  ['orig', 'subpopulation_0.0_label_0.0', 0.7219251336898396],
#  ['orig', 'subpopulation_0.0_label_1.0', 0.5201465201465202],
#  ['orig', 'subpopulation_0.0_label_1.0', 0.5007407407407407],
#  ['orig', 'subpopulation_0.0_label_1.0', 0.5007407407407407],
#  ['orig', 'subpopulation_1.0_label_0.0', 0.8703703703703703],
#  ['orig', 'subpopulation_1.0_label_0.0', 0.7058823529411765],
#  ['orig', 'subpopulation_1.0_label_0.0', 0.7058823529411765],
#  ['orig', 'subpopulation_1.0_label_1.0', 0.5220159151193634],
#  ['orig', 'subpopulation_1.0_label_1.0', 0.5124901393636603],
#  ['orig', 'subpopulation_1.0_label_1.0', 0.5124901393636603],
#  ['syn', 'entire_dataset', 0.5408426483233018],
#  ['syn', 'entire_dataset', 0.5078241859394776],
#  ['syn', 'entire_dataset', 0.5078241859394776],
#  ['syn', 'entire_dataset_label_0.0', 0.7977528089887641],
#  ['syn', 'entire_dataset_label_0.0', 0.7338129496402876],
#  ['syn', 'entire_dataset_label_0.0', 0.7338129496402876],
#  ['syn', 'entire_dataset_label_1.0', 0.5213226205191595],
#  ['syn', 'entire_dataset_label_1.0', 0.5043818649217107],
#  ['syn', 'entire_dataset_label_1.0', 0.5043818649217107],
#  ['syn', 'subpopulation_0.0_label_0.0', 0.8248175182481753],
#  ['syn', 'subpopulation_0.0_label_0.0', 0.75],
#  ['syn', 'subpopulation_0.0_label_0.0', 0.75],
#  ['syn', 'subpopulation_0.0_label_1.0', 0.514946418499718],
#  ['syn', 'subpopulation_0.0_label_1.0', 0.49980161354318214],
#  ['syn', 'subpopulation_0.0_label_1.0', 0.49980161354318214],
#  ['syn', 'subpopulation_1.0_label_0.0', 0.7734375],
#  ['syn', 'subpopulation_1.0_label_0.0', 0.7196969696969697],
#  ['syn', 'subpopulation_1.0_label_0.0', 0.7196969696969697],
#  ['syn', 'subpopulation_1.0_label_1.0', 0.5290498974709501],
#  ['syn', 'subpopulation_1.0_label_1.0', 0.5082933019124445],
#  ['syn', 'subpopulation_1.0_label_1.0', 0.5082933019124445],
#  ['reweigh', 'entire_dataset', 0.5478119935170178],
#  ['reweigh', 'entire_dataset', 0.5328195588626097],
#  ['reweigh', 'entire_dataset', 0.5328195588626097],
#  ['reweigh', 'entire_dataset_label_0.0', 0.77992277992278],
#  ['reweigh', 'entire_dataset_label_0.0', 0.7357142857142857],
#  ['reweigh', 'entire_dataset_label_0.0', 0.7357142857142857],
#  ['reweigh', 'entire_dataset_label_1.0', 0.5281491907107672],
#  ['reweigh', 'entire_dataset_label_1.0', 0.5184022824536377],
#  ['reweigh', 'entire_dataset_label_1.0', 0.5184022824536377],
#  ['reweigh', 'subpopulation_0.0_label_0.0', 0.7674418604651163],
#  ['reweigh', 'subpopulation_0.0_label_0.0', 0.7248677248677249],
#  ['reweigh', 'subpopulation_0.0_label_0.0', 0.7248677248677249],
#  ['reweigh', 'subpopulation_0.0_label_1.0', 0.5282012195121951],
#  ['reweigh', 'subpopulation_0.0_label_1.0', 0.5204888569374551],
#  ['reweigh', 'subpopulation_0.0_label_1.0', 0.5204888569374551],
#  ['reweigh', 'subpopulation_1.0_label_0.0', 0.7954545454545455],
#  ['reweigh', 'subpopulation_1.0_label_0.0', 0.753968253968254],
#  ['reweigh', 'subpopulation_1.0_label_0.0', 0.753968253968254],
#  ['reweigh', 'subpopulation_1.0_label_1.0', 0.5281045751633988],
#  ['reweigh', 'subpopulation_1.0_label_1.0', 0.5170293282876065],
#  ['reweigh', 'subpopulation_1.0_label_1.0', 0.5170293282876065],
#  ['dir', 'entire_dataset', 0.511984392419175],
#  ['dir', 'entire_dataset', 0.5105409064534846],
#  ['dir', 'entire_dataset', 0.5105409064534846],
#  ['dir', 'entire_dataset_label_0.0', 0.7499999999999999],
#  ['dir', 'entire_dataset_label_0.0', 0.7072368421052632],
#  ['dir', 'entire_dataset_label_0.0', 0.7072368421052632],
#  ['dir', 'entire_dataset_label_1.0', 0.5064027024903763],
#  ['dir', 'entire_dataset_label_1.0', 0.5068655147493595],
#  ['dir', 'entire_dataset_label_1.0', 0.5068655147493595],
#  ['dir', 'subpopulation_0.0_label_0.0', 0.7216981132075472],
#  ['dir', 'subpopulation_0.0_label_0.0', 0.7005649717514124],
#  ['dir', 'subpopulation_0.0_label_0.0', 0.7005649717514124],
#  ['dir', 'subpopulation_0.0_label_1.0', 0.5086206896551724],
#  ['dir', 'subpopulation_0.0_label_1.0', 0.5049011980706395],
#  ['dir', 'subpopulation_0.0_label_1.0', 0.5049011980706395],
#  ['dir', 'subpopulation_1.0_label_0.0', 0.8016528925619835],
#  ['dir', 'subpopulation_1.0_label_0.0', 0.7194244604316546],
#  ['dir', 'subpopulation_1.0_label_0.0', 0.7194244604316546],
#  ['dir', 'subpopulation_1.0_label_1.0', 0.5066568047337279],
#  ['dir', 'subpopulation_1.0_label_1.0', 0.5121633362293658],
#  ['dir', 'subpopulation_1.0_label_1.0', 0.5121633362293658],
#  ['egr', 'entire_dataset', 0.5099192146436241],
#  ['egr', 'entire_dataset', 0.5091837245383114],
#  ['egr', 'entire_dataset', 0.5091837245383114],
#  ['egr', 'entire_dataset_label_0.0', 0.8325791855203619],
#  ['egr', 'entire_dataset_label_0.0', 0.8135593220338984],
#  ['egr', 'entire_dataset_label_0.0', 0.8135593220338984],
#  ['egr', 'entire_dataset_label_1.0', 0.506231576769923],
#  ['egr', 'entire_dataset_label_1.0', 0.5069581472634749],
#  ['egr', 'entire_dataset_label_1.0', 0.5069581472634749],
#  ['egr', 'subpopulation_0.0_label_0.0', 0.8317757009345794],
#  ['egr', 'subpopulation_0.0_label_0.0', 0.751412429378531],
#  ['egr', 'subpopulation_0.0_label_0.0', 0.751412429378531],
#  ['egr', 'subpopulation_0.0_label_1.0', 0.5048786292241789],
#  ['egr', 'subpopulation_0.0_label_1.0', 0.49817625603012117],
#  ['egr', 'subpopulation_0.0_label_1.0', 0.49817625603012117],
#  ['egr', 'subpopulation_1.0_label_0.0', 0.8333333333333334],
#  ['egr', 'subpopulation_1.0_label_0.0', 0.8135593220338984],
#  ['egr', 'subpopulation_1.0_label_0.0', 0.8135593220338984],
#  ['egr', 'subpopulation_1.0_label_1.0', 0.5072715631574134],
#  ['egr', 'subpopulation_1.0_label_1.0', 0.5138953434334047],
#  ['egr', 'subpopulation_1.0_label_1.0', 0.5138953434334047]]

# %%
df = pd.DataFrame(advantage_metrics_arrays,columns=["Fairness", "MIA", "PPV"])
df
# Out:
#     Fairness                          MIA       PPV
# 0       orig               entire_dataset  0.536726
# 1       orig               entire_dataset  0.511522
# 2       orig               entire_dataset  0.511522
# 3       orig     entire_dataset_label_0.0  0.785714
# 4       orig     entire_dataset_label_0.0  0.711712
# ..       ...                          ...       ...
# 100      egr  subpopulation_1.0_label_0.0  0.813559
# 101      egr  subpopulation_1.0_label_0.0  0.813559
# 102      egr  subpopulation_1.0_label_1.0  0.507272
# 103      egr  subpopulation_1.0_label_1.0  0.513895
# 104      egr  subpopulation_1.0_label_1.0  0.513895
#
# [105 rows x 3 columns]

# %%
# Plotting without scaling y limis to 1
import seaborn as sns
sns.set_theme()
#sns.set_style('ticks')

g = sns.catplot(
    data=df, x="MIA", y="PPV", hue="Fairness",
    #palette={"male": "g", "female": "m"},
    markers=["^", "o", "x", "v", ">"], linestyles=["-", "--", "-.", ":", "-"],
    kind="point", height=8, aspect=1
)

plt.xticks(rotation=30)

g.set_axis_labels("Classifier Membership Inference Attacks", "Attacker's PPV" )

# %% [markdown]
# # Dataset Exploration for comparison with Shokri

# %%
import pandas as pd

# %%
# pd.DataFrame([dataset_orig.features, dataset_orig.labels]).drop_duplicates()

df = pd.DataFrame(dataset_orig.features, columns=dataset_orig.feature_names)

df["labels"] = dataset_orig.labels
df
#df.index
# Out:
#        decile3  decile1  race  cluster  lsat  ugpa  dob_yr  fulltime  fam_inc  \
# 0         10.0     10.0   0.0      1.0  44.0   3.5    69.0       1.0      5.0
# 1          4.0      5.0   0.0      2.0  29.0   3.5    69.0       1.0      4.0
# 2          7.0      8.0   0.0      1.0  37.0   3.4    68.0       1.0      3.0
# 3          7.0      8.0   0.0      1.0  43.0   3.3    67.0       1.0      4.0
# 4          2.0      3.0   0.0      4.0  41.0   3.3    64.0       1.0      4.0
# ...        ...      ...   ...      ...   ...   ...     ...       ...      ...
# 20793      8.0      9.0   0.0      5.0  42.0   3.0    67.0       1.0      4.0
# 20794      9.0      4.0   0.0      3.0  29.5   3.5    68.0       1.0      4.0
# 20795      1.0      1.0   0.0      3.0  33.0   3.1    69.0       1.0      3.0
# 20796      5.0      4.0   0.0      3.0  32.0   3.0    67.0       0.0      3.0
# 20797      3.0      9.0   0.0      4.0  36.0   3.2    67.0       1.0      3.0
#
#        gender  tier  indxgrp  indxgrp2  labels
# 0         0.0   4.0      6.0       8.0     1.0
# 1         0.0   2.0      5.0       5.0     1.0
# 2         1.0   4.0      6.0       7.0     1.0
# 3         0.0   4.0      6.0       8.0     1.0
# 4         0.0   5.0      6.0       7.0     1.0
# ...       ...   ...      ...       ...     ...
# 20793     1.0   6.0      6.0       7.0     1.0
# 20794     1.0   3.0      5.0       5.0     1.0
# 20795     1.0   3.0      5.0       5.0     0.0
# 20796     1.0   3.0      5.0       5.0     1.0
# 20797     1.0   5.0      6.0       6.0     1.0
#
# [20798 rows x 14 columns]

# %%
df[["age", "labels"]].value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df[["age", "labels"]].value_counts(normalize=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['age'] not in index"

# %%
df.drop_duplicates()

# %% [markdown]
# ## DT Accuracy

# %%
get_orig_model_metrics(dataset_orig_train, dataset_orig_test, unprivileged_groups, f_label, uf_label, BASELINE, SCALER)
# Out:
# [INFO]: training decision tree
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.52      0.69       267
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.52       267
#    macro avg       0.50      0.26      0.34       267
# weighted avg       1.00      0.52      0.69       267
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      1.00      1.00      4242
#
#     accuracy                           1.00      4242
#    macro avg       0.50      0.50      0.50      4242
# weighted avg       1.00      1.00      1.00      4242
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.46      0.63       263
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.46       263
#    macro avg       0.50      0.23      0.32       263
# weighted avg       1.00      0.46      0.63       263
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      1.00      1.00      5627
#
#     accuracy                           1.00      5627
#    macro avg       0.50      0.50      0.50      5627
# weighted avg       1.00      1.00      1.00      5627
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.22      0.36       248
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.22       248
#    macro avg       0.50      0.11      0.18       248
# weighted avg       1.00      0.22      0.36       248
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.98      0.99      4366
#
#     accuracy                           0.98      4366
#    macro avg       0.50      0.49      0.49      4366
# weighted avg       1.00      0.98      0.99      4366
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.21      0.35       262
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.21       262
#    macro avg       0.50      0.10      0.17       262
# weighted avg       1.00      0.21      0.35       262
#
# Classification report for train:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.98      0.99      5523
#
#     accuracy                           0.98      5523
#    macro avg       0.50      0.49      0.50      5523
# weighted avg       1.00      0.98      0.99      5523
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ilham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'train_0_0': 0.5243445692883895,
#  'train_0_1': 0.9964639321074965,
#  'train_1_0': 0.46387832699619774,
#  'train_1_1': 0.997334281144482,
#  'test_0_0': 0.21774193548387097,
#  'test_0_1': 0.9759505267979844,
#  'test_1_0': 0.2099236641221374,
#  'test_1_1': 0.9826181423139598}

# %%
train_test_egr
# Out:
# {'train_0_0': 0.4794007490636704,
#  'train_0_1': 0.9983498349834984,
#  'train_1_0': 0.4600760456273764,
#  'train_1_1': 0.9987559978674249,
#  'test_0_0': 0.17338709677419356,
#  'test_0_1': 0.9777828676133761,
#  'test_1_0': 0.12595419847328243,
#  'test_1_1': 0.9817128372261452}
