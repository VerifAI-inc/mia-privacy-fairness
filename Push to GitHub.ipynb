# %% [markdown]
# ## Setup for Google Colab

# %% [markdown]
# First, create personal access token in GitHub and put it in appropriate folder, then change the folder in the below code accordingly:

# %%
from google.colab import drive
drive.mount('/content/drive')

with open('/content/drive/MyDrive/Senior Design Project/mia-privacy-fairness/github_token.txt') as f:
    token = f.read().strip()

username = 'inovruzova' # replace with yours
repository = 'mia-privacy-fairness' # replace with your repo

# !git clone https://{token}@github.com/{username}/{repository}.git
# Out:
# Mounted at /content/drive
# Cloning into 'mia-privacy-fairness'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 26 (delta 2), reused 20 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 900.32 KiB | 6.87 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd {repository}
# Out:
# /content/mia-privacy-fairness

# %%
# %ls
# Out:
# active_poison.py  explainer.py                     MIA_Attack_Result.py  README.md
# active_select.py  fair_ml.py                       mitigators.py         test_algorithms.py
# adv_synth.py      fairness_notebook_bank_dt.ipynb  models.py
# data_utils.py     membership_infer_attack.py       oversample.py
# environment.yml   metrics_utils.py                 plot_utils.py

# %% [markdown]
# ### After doing changes...

# %%
# !cp "/content/drive/MyDrive//Senior Design Project/mia-privacy-fairness/Push to GitHub.ipynb" /content/{repository}

# %%
# !git add --all

# %% [markdown]
# Please tell me who you are.
#
# Run
#
#   `git config --global user.email "you@example.com"`
#
#   `git config --global user.name "Your Name"`
#
# to set your account's default identity.
#
# Omit --global to set the identity only in this repository.

# %%
email = "ilhama.nnovruzova@gmail.com" # replace with yours
name = "Ilhama" # replace with yours

# %%
# !git config --global user.email {email}
# !git config --global user.name {name}

# %%
# !git commit -a -m "trial commit from colab"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
